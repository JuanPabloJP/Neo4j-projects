# %% [markdown]
# ## Nota: Descomprimir el archivo PROFECO_2015_vEspecial.csv en el folder import de Node4j y poner este notebook ahí mismo.

# %%
import pandas as pd

# %% [markdown]
# El CSV viene con un encoding ISO-8859-1, por lo que primero lo pasamos a UTF-8

# %%
df = pd.read_csv("Datos/PROFECO_2015_vEspecial.csv",encoding='ISO-8859-1')
df.head(2)
# Out:
#    AÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂO UNIDAD ADMINISTRATIVA  \
# 0                                2015        AGUASCALIENTES
# 1                                2015        AGUASCALIENTES
#
#   NUMERO DE EXPEDIENTE DE VERIFICACION FECHA DE VISITA  \
# 0                      702/000009/2015      2015-01-05
# 1                      702/000012/2015      2015-01-06
#
#   NORMA OFICIAL MEXICANA VERIFICADA                        TIPO DE PRODUCTO  \
# 0                 NOM-015-SCFI-2007  MUÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂECOS
# 1                 NOM-004-SCFI-2006                          ROPA CABALLERO
#
#                             DESCRIPCION DEL PRODUCTO  \
# 0  EN EMPAQUE DE CARTON ESTAMPADO Y PLASTICO RIGI...
# 1  CAMISA PARA CABALLERO EN COLOR AZUL MARINO DE ...
#
#                    RAZON SOCIAL VISITADA        GIRO COMERCIAL  \
# 0  JULIO CEPEDA JUGUETERIAS S.A. DE C.V.            JUGUETERIA
# 1               C&A DE MEXICO S. DE R.L.  TIENDA DEPARTAMENTAL
#
#         MUNICIPIO         ENTIDAD                INCUMPLIMIENTO  \
# 0  AGUASCALIENTES  AGUASCALIENTES  NO SE DETECTO INCUMPLIMIENTO
# 1  AGUASCALIENTES  AGUASCALIENTES  NO SE DETECTO INCUMPLIMIENTO
#
#   CLASIFICACION RESULTADO PRODUCTO
# 0                  VISITA CORRECTA
# 1                  VISITA CORRECTA

# %%
df.to_csv('PROFECO_2015_vEspecial.csv', index=False, encoding='utf-8')

# %%
from neo4j import GraphDatabase

# %% [markdown]
# Ponemos nuestro usuario y contraseña:

# %%
usuario = 'neo4j'
contra = 'neo4j'

# %%
#Genero Driver. NOTA: Dejar el puerto como esta, es otra conexión que el web portal
driver = GraphDatabase.driver("bolt://localhost:7687", auth=(usuario, contra), encrypted = False)
#Eliminamos constraints existentes
with driver.session() as s:
    # Drop constraints / indices
    for c in s.run("CALL db.constraints"):
        s.run("DROP CONSTRAINT " + c[0])
    for c in s.run("CALL db.indexes"):
        s.run("DROP INDEX " + c[1])
    s.run("MATCH (n) DETACH DELETE n")

# %% [markdown]
# Cargamos CSV a la base

# %%
with driver.session() as s:
    s.run("CREATE CONSTRAINT ON (e:Entidad) ASSERT e.nombre IS UNIQUE;")
    s.run("CREATE INDEX ON :Municipio (nombre);")
    s.run("CREATE INDEX ON :Municipio (nombre, entidad);")
    s.run("CREATE INDEX ON :Tienda (nombre);")
    s.run("CREATE INDEX ON :Tienda (nombre, giro);")
    s.run("CREATE INDEX ON :Producto (nombre);")
    s.run("CREATE INDEX ON :Producto (nombre, categoria);")
    s.run("CREATE CONSTRAINT ON (c:Categoria) ASSERT c.nombre IS UNIQUE;")
    s.run("CREATE INDEX ON :Usuario (id);")
    s.run("CREATE INDEX ON :Compra (id);")
    print("Indices creados.")
    s.run("""LOAD CSV WITH HEADERS FROM "file:///PROFECO_2015_vEspecial.csv" AS row
             MERGE (e:Entidad {nombre: row.ENTIDAD})
             MERGE (m:Municipio {nombre: row.MUNICIPIO, entidad: row.ENTIDAD})
             MERGE (e) <-[r1:Es_Municipio]- (m);
             """)
    print("Entidades/Municipios y sus relaciones creadas.")
    s.run("""LOAD CSV WITH HEADERS FROM "file:///PROFECO_2015_vEspecial.csv" AS row
             MERGE (t:Tienda {nombre: row.`RAZON SOCIAL VISITADA`, giro: row.`GIRO COMERCIAL`, municipio:row.MUNICIPIO , entidad: row.ENTIDAD});
             """)
    print("Tiendas creadas.")
    s.run("""MATCH (t:Tienda), (m: Municipio)
             WHERE t.municipio = m.nombre and t.entidad = m.entidad
             CREATE (t) -[r:Se_Encuentra_En]-> (m);
             """)
    print("Relaciones entre Tiendas y Municipios creadas.")
    s.run("""LOAD CSV WITH HEADERS FROM "file:///PROFECO_2015_vEspecial.csv" AS row
             MERGE (c:Categoria {nombre: row.`TIPO DE PRODUCTO`});
             """)
    print("Categorías creadas.")
    s.run("""LOAD CSV WITH HEADERS FROM "file:///PROFECO_2015_vEspecial.csv" AS row
             MERGE (p:Producto {nombre: row.`DESCRIPCION DEL PRODUCTO` ,categoria: row.`TIPO DE PRODUCTO`});
             """)
    print("Productos creados.")
    s.run("""MATCH (p:Producto), (c:Categoria)
             WHERE p.categoria = c.nombre
             CREATE (p) -[r:Categorizado_Como]-> (c);
             """)
    print("Relaciones entre Categorías y Productos creadas.")
    s.run("""LOAD CSV WITH HEADERS FROM "file:///PROFECO_2015_vEspecial.csv" AS row
             MATCH (e:Entidad {nombre: row.ENTIDAD}) <-[r1:Es_Municipio]- (m:Municipio {nombre: row.MUNICIPIO}) <-[r2:Se_Encuentra_En]- (t:Tienda {nombre: row.`RAZON SOCIAL VISITADA`, giro: row.`GIRO COMERCIAL`})
             MATCH (p:Producto {nombre: row.`DESCRIPCION DEL PRODUCTO`}) -[r:Categorizado_Como]-> (c:Categoria {nombre: row.`TIPO DE PRODUCTO`})
             CREATE (t) -[r3:Vende {incumplimiento: row.INCUMPLIMIENTO}]-> (p);
             """)
    print("Relaciones entre Tiendas y Productos creadas.")
# Out:
# Indices creados.
# Entidades/Municipios y sus relaciones creadas.
# Tiendas creadas.
# Relaciones entre Tiendas y Municipios creadas.
# Categorías creadas.
# Productos creados.
# Relaciones entre Categorías y Productos creadas.
# Relaciones entre Tiendas y Productos creadas.

# %%
flatten = lambda l: [item for sublist in l for item in sublist]

lista_productos = []
with driver.session() as s:
    lista_productos = flatten(s.run("MATCH (n:Producto) return n.nombre;").values())

# %%
lista_productos
# Out:
# ['EN EMPAQUE DE CARTON ESTAMPADO Y PLASTICO RIGIDO  MUÃ\x91ECA PARA NIÃ\x91A DE LA MARCA BARBIE DE ORIGEN CHINA. CONTENIDO UNA PIEZA MODELO BARBIE BASICA LIFE FASHION CON NUMERO DE LOTE T7439 INDICA INFORMACION IMPORTANTE PARA CONSULTA  IMPO',
#  'CAMISA PARA CABALLERO EN COLOR AZUL MARINO DE LA MARCA C & A DE ORIGEN BANGLADESH  IMPORTADO POR C & A MEXICO  DE COMPOSICION EN 64% ALGODON  32% POLIAMIDA Y 4% ELASTANO CON NUMERO DE LOTE 252959. CONTIENE INSTRUCCIONES DE CUIDADO',
#  'UNA BOTELLA BRANDY DE LA MARCA TORRES 10 CON LA LEYENDA 100% DE UVA  GRAN RESERVA CON 38% ALC. VOL. CON UN CONTENIDO NETO DE 700ML CON SELLO DE SHCP CON LA LEYENDA "EL ABUSE EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD"',
#  'ENVASE DE VIDRIO CONTENIDO BRANDY DE LA MARCA AZTECA DE ORO  SOLERA RESERVADA CON 38% ALC. VOL. CONTENIDO NETO 700ML HECHO ENMEXICO PRODUCTO 100% DE UVA FABRICADO POR INDUSTRIAS VINICOLAS PEDRO DOMER  S.A. DE C.V.',
#  'BOTELLA DE VIDRIO CONTENIDO BRANDY 100% UVA GRAN RESERVA MARCA TORRES 10 CONT. NET. 700ML  38%ALC. VOL. ORIGEN ESPAÃ\x91A',
#  'BOTELLA DE VIDRIO CONTENIDO BRANDY 100% DE UVA MARCA TORRES 10 CONTENIDO NETO 700 ML  38% ALC. VOL. ORIGEN ESPAÃ\x91A',
#  'ZAPATOS EN COLOR ROJO PARA CABALLERO DE LA MARCA PUMA DE LA TALLA 24 CORTE PIEL VACUNO  FORRO TEXTIL  SUELA SINTETICA HECHO EN INDONESIA IMPORTADO Y DISTRIBUIDO POR DA MEXICO CALZADO Y ARTICULOS DEPORTIVOS S. DE R.L. DE C.V.',
#  'VESTIDO CORTO ESTILO 12249  TALLA 13  100% POLIESTER  FORRO NACIONAL. LAVAR EN SECO. NO USAR BLANQUEADOR. PLANCHAR CON LIENZO HECHO EN MEXICO DE LA MARCA LA DIFFERENCE  S.A. DE C.V.',
#  'EN ENVASE DE VIDRIO CONTENIDO 750 ML DE RON TIPO SOLERA DE LA MARCA BACARDI CON 38% ALC. VOL. HECHO EN MEXICO CON LEYENDA INSERTA: EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD"',
#  'BOTELLA DE VIDRIO CONTENIDO TEQUILA 100% DE AGAVE MARCA GRAN CENTENARIO REPOSADO. HECHO EN MEXICO CONTENIDO NETO 950 ML 35% ALC. VOL. CON LEYENDA DE ABUSO DEL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD',
#  'ENVSE DE VIDRIO CONTENIDO BRANDY PENEDES 100% DE UVA GRAN RESERVA TORRES 10 ORIGEN ESPAÃ\x91A CON CONTENIDO NETO 750 ML  38% ALC. VOL. CON LEYENDA "ESTE PRODUCTO EN EXCESO ES NOCIVO PARA LA SALUD" LOTE 6424821',
#  'BOTELLA DE VIDRIO CONTENIDO BRANDY 100% DE UVA GRAN RESERVA MARCA TORRES 10 CONT. NET. 700ML  38% ALC. VOL. DE ORIGEN ESPAÃ\x91A CON LA LEYENDA "EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO ES NOVICO PARA LA SALUD" LOTE L414211',
#  'BOTELLA DE SOLERA GRAN RESERVA DE LA MARCA TORRES 5 CON UN CONTENIDO DE 700ML Y 38% ALC. VOL.  100% UVA CON LA LEYENDA"EL ABUSO EN ELCONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD"',
#  'ENVASE DE VIDRIO CON CONTENIDO NETO DE 355 ML DE CERVEZA NEGRA DE LA MARCA MODELO CON 5.3 ALC. VOL. HECHO EN MEXICO CON LA LEYENDA "EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD"',
#  'ENVASE DE VIDRIO CONTENIDO 700 ML DE TEQUILA REPOSTADO  100% DE AGAVE  CON 35% VOL. ALC. HECHO EN MEXICO CON NeMERO DE LOTE 35613 DE LA MARCA CENTENARIO',
#  'ENVASE DE VIDRIO CONTENIDO MEZCAL  750ML 100% DE AGAVE  HECHO EN MEXICO  38% VOL. ALC. HECHO EN MEXICO DE LA MARCA EL SEÃ\x91ORIO  MEZCAL JOVEN CON GUSANO',
#  'ENVASE DE VIDRIO CON CONTENIDO NETO DE 700ML DE BRANDY IMPERIAL  100% DE UVA CON 38% ALC. VOL. DE LA MARCA TORRES 10',
#  'UNA BOTELLA DE TEQUILA DE LA MARCA GRAN CENTENARIO CON LA LEYENDA 100% AGAVE CON UN CONTENIDO NETO DE 700ML Y 35% ALC. VOL. CON LA LEYENDA "EL ASUO EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD" CON NUMERO DE LOTE L073714',
#  'UNA BOTELLA DE MEZCAL DE LA MARCA ALACRAN CON CONTENIDO NETO 750ML  46% ALC. VOL. Y 100% AGAVE ESPADIN.PRODUCCION ARTESANAL CON LA LEYENDA "EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD"',
#  'UNA BOTELLA DE BRANDY DE LA MARCA TORRES 10 CON CONT. NETO DE 700ML  38% ALC. VOL. DE ORIGEN ESPAÃ\x91A  CON LEYENDA "EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD"',
#  'EMPAQUE DE PLASTICO CONTENIDO 357 GR DE ALIMENTO EN POLVO PARA PREPARAR BEBIDA FORTIFICADA SABOR A CHOCOLATE DE LA MARCA NESTLE  ENRIQUECIDO CON VITAMINAS MINERALES Y HIERRO CON INSTRUCCION DE PREPARACION HECHO EN MEXICO CON CARACT',
#  'ENVASE DE PLASTICO DE LA MARCA KNORR CONTENIDO 95 GR DE SOPA DE FIDEOS  FORTIFICADA CON VITAMINAS EMPAQUE PARA CUATROPORCIONES RINDIENDO UN LIGRO DE AGUA MISMA CON INFORMACION NUTRIMENTAL CON CARACTERISTICAS DEL PRODUCTO EN EL EMPA',
#  'EMPAQUE DE PLASTICO CONTENIDO 25 GR DE POLVO PARA PREPARAR GELATINA BAJA EN CALORIAS SABOR A FRESA CUAL RINDE UN LIGRO DE LA MARCA JELLO LIGHT  CON DESCRIPCION DE INGREDIENTES  INSTRUCCIONES DE PREPARACION  CADUCIDAD DE OCTUBRE 201',
#  'EMPAQUE DE PLASTICO CONTENIDO 227 GR DE SUSTITUTO DE CREMA PARA CAFE EN POLVO LIBRE DE COLESTEROL Y GRASAS TRANS DE LAM ARCA CALKINS HECHO EN EUA. CON TABLA DE INFORMACION NUTRIMENTAL  DESCRIBIENDO CARACTERISTICAS DEL PRODUCTO  MIS',
#  'LOMO DE ATUN MARCA DOLORES CONT. NET. 295 GR HECHO EN MEXICO',
#  'VELADORA MARCA CRISTO REY CONT. NET. 1 PIEZA HECHO EN MEXICO',
#  'FRIJOLES NEGROS REFRITOS MARCA LA SIERRA CONT. NET. 580 GR HECHO EN MEXICO',
#  'LATA DE ATUN  DE LOMO ALETA AMARILLA',
#  'EMPAQUE DE PLASTICO CONTENIDO 18 HUEVOS BLANCOS',
#  'BOTELLA DE TEQUILA CONTENIDO NETO 950 ML CON 35% ALC.',
#  'BOTELLA DE BRANDY CONTENIDO NETO 700 ML 38% ALC.',
#  'BOTELLA DE WHISKY CONENIDO 750 ML CON 40% ALC.',
#  'CUMPLE CON LA NORMA',
#  'CUMPLE CON LA NORMA',
#  'BOTELLA DE TEQUILA JOSE CUERVO DE 695 ML 100% AGAVE AZUL CON 38% ALC. VOL.',
#  'BOTELLA DE BRANDY TORRES 5 CONTENIDO NETO 700 ML CON 38% ALC. VOL.',
#  'BOTELLA DE TEQUILA CONTENIDO NETO 950ML 35% ALC.',
#  'BOTELLA DE BANDY CONTENIDO NETO DE 700ML  100% DE UVA 38% ALC.',
#  'BOTELLA DE WHISKY CONTENIDO NETO 750ML',
#  'BOTELLA DE VIDRIO CON TEQUILA REPOSADO 100% DE AGAVE AZUL  CONTENIDO NETO DE 695 ML CON 38% ALC.',
#  'BOTELLA DE VIDRIO CON WHISKY AÃ\x91EJADO BLACK LABEL CONTENIDO NETO 750ML',
#  'SUERO REHIDRATANTE SABER FRESA ELECTROLIT MARCA PISA CONTENIDO NETO 625 ML',
#  'ENVASE DE VIDRIO CONTENIDO JUGO DE MANZANA Y CIRUELA PASA  GERBER MARCA NESTRLE CONTENIDO NETO 175 ML',
#  'CUMPLE CON LA NOM',
#  'CUMPLE CON LA NOM',
#  'CHAROLA DE HUEVO CONTENIDO 12 PIEZAS',
#  'ACEITE MARCA SABRO SANO DE 746 ML VEGETAL COMESTIBLE DE SOYA Y CANOLA',
#  'CUMPLE CON LA NOM',
#  ' CUMPLE CON LA NOM',
#  'TRAJE DE BAÃ\x91O PARA MUJER EN UNA PIEZA EN COLOR NEGRO  TALLA 7. 82% POLIAMIDA  18% ELASTANO  FORRO 100%  POLIAMIDA. HECHO EN MEXICO POR: CREACIONES GUZ  S.A. DE C.V. CON INSTRUCCIONES DE LAVADO DE LA MARCA ZONE BEACH',
#  'TRAJE DE BAÃ\x91O PARA DAMA DE DOS PIEZAS DE COLOR ROZA TALLA G-11 DE LA MARCA ZONE BEACH CUERPO CALZON 83% POLIAMIDA  17% ELASTANO  FORRO 100% POLIAMIDA CON INSTRUCCIONES DE LAVADO. HECHO EN MEXICO POR CREACIONES GUZ S.A. DE C.V.',
#  'TRAJE DE BAÃ\x91O PARA NIÃ\x91O  TALLA MEDIANA Y COLOR AZUL MARINO DE LA MARCA VOIT  HECHO EN MEXICO CON INSTRUCCIONES DE LAVADO',
#  'TRAJE DE BAÃ\x91O PARA DAMA DE BAÃ\x91O  TALLA 34  MARCA NIKE  FABRICADO POR PERRY ELLIS MEXICO  S. DE R.L. DE C.V.  HECHO EN MEXICO CON INSTRUCCIONES DE USO Y LAVADO',
#  'TRAJE DE BAÃ\x91O DE LA MARCA ARENA  COLOR AZUL MARINO TALLA 36  HECHO EN CHINA IMPORTADO POR ARENA CONTINENTAL IMPORTACIONES  S.A. DE C.V. CON INDICACIONES DE LAVADO',
#  'TRAJE DE BAÃ\x91O PARA DAMA TALLA 6  COLOR NEGO CON AZUL  HECHO EN CHINA  79% POLIAMIDA  21% ELASTANO  IMPORTADO POR PVH MEXICO S.A. DE C.V.  CON INSTRUCCIONES DE LAVADO',
#  'tequila gran centenario plata contenido neto 700 mililitros 100% de agave 35% alc. vol. de origen mexico',
#  'envase de vicrio ron de la marca matusalem de origen cuba  contenido neto 750 mililitros importado por casa cuervo',
#  'Botella de vidrio contenido tequila  700 ml  40% alc.',
#  'Botella de vidrio contenido cerveza  355 ml  con 4 5% alc. vol.',
#  'botella de vicrio conteniendo tequila reposado 100% de agave marca el jimador contenido neto 700ml  35% alc. vol. hecho en mexico por casa herradura en camino a la barranca del tecuane no. 10 amatitan jalisco c.p. 45380 leyenda el',
#  'cerveza lager especial marca dos equis contenido neto 325 mililitros 4.3 de alc. vol. hecho en mexico por cervecedria cuauhtemoc moctezuma',
#  'BOTELLA DE VIDRIO CONTENIDO TEQUILA REPOSADO 100% DE AGAVE 700ML 40% ALC. VOL.',
#  'BOTELLA DE VIDRIO CON CERVEZA PREMIUM CONTENIDO NETO 355 ML',
#  'ENVASE DE VRIDRIO CON BRANDY CONTENIDO NETO 700 ML 100% DE UVA',
#  'ENVASE DE VIDRIO CON TEQUILA 100% DE AGAVE CONTENIDO NETO 700ML',
#  'ENVASE DE VIDRIO TEQUILA REPOSADO DE LA MARCA JOSE CUERVO TRADICIONAL CON CONTENIDO NETO DE 695ML  100% DE AGAVE AZUL  INDICA 28% ALC. VOL. HECHO EN MEXICO OSTENTA LA LEYENDA "EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA',
#  'ENVASE DE VIDRIO BOTELLA DE LA MARCA GRAN RESERVA TORRES 10 DE ORIGEN ESPAÃ\x91CA CON CONT. NET. DE 700ML  100% DE UVA INDICA 38% ALC. VOL. HECHO EN ESPAÃ\x91A Y OSTENTA LA LEYENDA "EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA SA',
#  'BOTELLA DE TEQUILA REPOSADO CONTENIDO 695 ML 100% AGAVE AZUL',
#  'BOTELLA DE VIDRIO CON BRANDY 700ML 100% UVA',
#  'BOTELLA DE VIDRIO CONTENIDO TEQUILA REPOSADO 100% DE AFAVE AZUL JOSE CUERVO TRADICIONAL CONT. NET. 695ML  38% ALC. VOL. HECHO EN MEXICO CON LA LEYENDA "EL ABUSO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD"',
#  'BOTELLA DE VIDRIO CONTENIDO CERVEZA CLARA CORONO EXTRA CONT. NET. 355ML  4.5% ALC. VOL. HECHO EN MEXICO POR CERVECERIA MODELO  S.A. DE C.V. CON LA LEYENDA "EL ABUSO EN EL CONSUDMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD"',
#  'BOTELLA DE VIDRIO CONTENIDA TEQUILA REPOSADO 100% AGAVE DE 750 ML',
#  'BOTELLA DE VIDRIO CONTENIDO CERVEZA DE 355 ML',
#  'BOTELLA DE VIDRIO CONTENIDO TEQUILA AÃ\x91EKO 100% DE AGAVE CONT. NET. 750ML  40% ALC. VOL. HECHO EN MEXICO POR CASA HERRADURA. CON LA LEYENDA "EL ABUSO DEL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD"',
#  'ENVASE DE VIDRIO CONTENIDO CERVEZA CLARA MARCA PACIFICO CONT. NET. 355ML 4.5% ALC. VOL. HECHO EN MEXICO POR CERVECERIA DEL PACIFICO S. DE R.L. DE C.V. CON LA LEYENDA "EL ABUSO DEL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD"',
#  'BOTELLA DE VIDRIO CONTENIDO TEQUILA AÃ\x91EJO 100% DE AGAVE  CENTENARIO  CONT  NET  695 ML  38% ALC. VOL. HECHO EN MEXICO CON LA LEYENDA "EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD"',
#  'BOTELLA DE VIDRIO  CONTENIDO CERVEZA OSCURA  MARCA INDIO. CONT. NET. 320 ML  4.1 % ALC. VOL. HECHO EN MEXICO POR CERVECERIA CUAUTHEMOC MOCTEZUMA  S.A. DE  C.V. CON LA LEYENDA PRECAUTORIA DE CONSUMO',
#  'BOTELLA DE VIDRIO CONTENIDO TEQUILA REPOSADO 100% DE AGAVE AZUL  JOSE CUERVO TRADICIONAL CONT. 695ML  38% ALC. VOL. HECHO EN MEXICO CON LA LEYENDA "EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD"',
#  'ENVASE EN ALUMINIO 100%  CONTENIDO CERVEZA CLARA LIGHT  MARCA TECATE  CONT. NET. 355ML  3.9% ALC. VOL. HECHO EN MEXICO CON LEYENDA PRECAUTORIA',
#  'EN ENVASE DE VIDRIO TEQUILA DE LA MARCA EL JIMADOR 100% AGAVE CON CONTENIDO NETO DE 700ML HECHO EN MEXICO DE 38% ALC. VOL. PRODUCIDO EN CASA HERRADURA. OSTENTA LA LEYENDA "EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA S',
#  'EN ENVASE DE VIDRIO BRANDY DE LA MARCA AZTECA DE ORO RESERVADA CONT. NET. 700ML 100% UVA CON 38% ALC. VOL. HECHO EN MEXICO Y OSTENTA LA LEYENDA EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD',
#  'EN ENVASE DE VIDRIO TEQUILA DE LA MARCA JOSE CUERVO TRADICIONAL REPOSADO 100% DE AGAVE AZUL DE ORIGEN CON CONTENIDO NETO DE 695ML CON 38% ALC. VOL. HECHO EN MEXICO CON LA LEYENDA "EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO P',
#  'EN ENVASE DE VIDRIO BRANDY DE LA MARCA GRAN RESERVA TORRES 10  100% DE UVA DE CONTENIDO NETO 700ML CON 38% ALC. VOL. DE ORIGEN ESPAÃ\x91A. OSTENTA LA LEYENDA EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD',
#  'ENVASE DE VIDRIO TEQUILA REPOSADO DE LA MARCA ANTIGUO DE HERRADURA  100% DE AGAVE CON CONTENIDO NETO DE 700ML CON 38% Y ALC. VOL.  PRODUCIDO EN CASA HERRADURA Y OSTENTA LA LEYENDA "EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO',
#  'EN ENVASE DE VIDRIO DE BRANDY DE LA MARCA AZTECA DE ORO SOLERA RESERVADO 100% UVA  CON CONTENIDO NETO 700ML  CON 38% ALC. VOL. HECHO EN MEXICO POR INDUSTRIASL VINICOLAS PEDRO DOMEQ  S.A. DE C.V. Y OSTENTA LA LEYENDA "EL ABUSO EN EL',
#  'BOTELLA DE VIDRIO CONTENIDO TEQUILA AÃ\x91EKO 100% DE AGAVE HECHO EN MEXICO CONT. NET. DE 750ML 35% ALC. VOL. POR CASA HERRADURA CON LA LEYENDA "EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD"',
#  'BOTELLA DE VIDRIO CONTENIDO CERVEZA OSCURA MARCA NEGRA MODELO CONT. NET. 355ML 5.3# ALC. VOL. HECHO EN MEXICO POR CERVECERIA MODELO S. DE R.L. DE C.V. CON LA LEYENDA EN EL ABUSO DEL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA ASALUD',
#  'ENVASE DE VIDRIO CON BRANDY 100% UVA DE 700 ML',
#  'ENVASE DE ALUMINIO CONTENIDO CERVEZA TIPO VIENS MARCA VICTORIA CONTENIDO NETO 435 ML 4.0% ALC. VOL. HECHO EN MEXICO POR CERVECERIA MODELO S. DE R.L. DE C.V. CON LA LEYENDA "EL ABUSO DEL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SA',
#  'EN ENVASE DE VIDRIO CONTENIDO CERVEZA CORONA EXTRA CLARA CONTENIDO NETO 355ML 4.5% ALC. VOL. HECHO EN MEXICO POR CERVECERIA MODELO  S.A. DE C.V. CON LA LEYENDA "EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD"',
#  'BOTELLA DE BRANDY DE 700 ML',
#  'EN ENVASE DE VIDRIO CON CERVEZA DE LA MARCA CORONA EXTRA CON UN CONTENIDO NETO DE 355 ML HECHO EN MEXICO CON 4.5% ALC. VOL. ELABORADO POR CERVECERIA MODELO  S.A. DE C.V. OSTENTA LA LEYENDA "EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO E',
#  'BOTELLA DE VIDRIO CONTENIDO BRANDY 100% DE UVA CONT. NET. 700ML 38% ALC. VOL. HECHO EN ESPAÃ\x91A MARCA TORRES 5 CON LEYENDA "EL ABUSO DEL CONSUMO ES NOCIVO PARA LA SALUD"',
#  'BOTELLA DE VIDRIO CONTENIDO TEQUILA REPOSADO 100% AGAVE MARCA HERRADURA CONT. NET. 700 ML  40% ALC. VOL. HECHO EN MEXICO POR CASA HERRADURA. LEYENDA PRECAUTORIA "EL ABUSO EN EL CONSUMO DE ESTE PRODCUTO ES NOCIVO PARA LA SALUD"',
#  'BOTELLA DE VIDRIO  BRANDY  CONTENIDO 700ML',
#  'BOTELLA DE BRANDY DE TORRES 15 700 ML',
#  'BOTELLA DE VIDRIO CONTENIDO WHISKY ESCOCES AÃ\x91EJADOS MARCA GRAN OLD PARR ORIGEN ESCOCIA CONT. NET. 750ML  40% ALC. VOL. CON LA LEYENDA "EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD"',
#  'EN ENVASE DE VIDRIO DE BRANDY DE LA MARCA TORRES 10 GRAN RESERVA CON UN CONT. NET. DE 700ML  100% DE UVA  CON 38% ALC. VOL. OSTENTA LALEYENDA "EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD"',
#  'ESTUCHE DE CARTON CONTENIDO 80 PIEZAS TRENZADORA ESTUCHE  DONAS GANCHITO SELECCIONADOR ACCESORIOS PARA PEINAR. NO RECOMENDADO PARA NIÃ\x91OS MENORES DE 36 MESES POR CONTENER PIEZAS PEQUEÃ\x91AS. MANTENER ALEJADO A LOS NIÃ\x91OS PEQUEÃ\x91OS Y ANIM',
#  'EN ENVASE DE VIDRIO  BOTELLA DE BRANDY DE LA MARCA TORRES 10 GRAN RESERVA CON CONT. NET. DE 700ML  100% DE UVA CON 38% ALC. VOL. HECHO EN ESPAÃ\x91A. OSTENTA LA LEYENDA "EL ABUSO EN EL CONSUMO QUE ESTE PRODUCTO ES NOCIVO PARA LA SALUD"',
#  'BOTELLA DE VIDRIO CONTENIDO TEQUILA BLANCO 100% AGAVE',
#  'BOTELLA DE VIDRIO CONTENIDO BRANDY 100% DE UVA DE 700 ML',
#  'SET DE PORTAVASOS 2 PIEZAS',
#  'ENVASE DE VIDRIO CONTENIDO WHISKY',
#  'ENVASE DE VIDRIO CONTENIDO BRANDY 100% DE UVA CONT. NETO 700 ML',
#  'UNA BOTELLA DE VIDRIO DE BRANDY DE LA MARCA TORRES 5  IMPERIAL BRANDY  CON CONTENIDO NETO DE 700 ML  100% UVA DE ORIGEN ESPAÃ\x91A CON 38% ALC. VOL. OSTENTA LA LEYENDA "EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD"',
#  'UN PAR DE ZAPATOS DE COLOR NEGRO PARA DAMA DEL NUMERO 25.5 CM  DE LA MARCA DOGI  DE ORIGEN MEXICO  MODELO E622  CORTE VACUNO  FORRO DE CERDO  SUELA SINTETICA',
#  'UN SET DE COCINA QUE INCLUYE UN MANDIL  UNA AGARRADERA Y UN GUANTE DE LA MARCA HOME ACCES DE ORIGEN CHINA IMPORTADO POR HOME  CREATE PRODUCTS  S.A. DE C.V.',
#  'UN JUEGO DE CUCHILLOS DE ACERO INOXIDABLE CONTENIDO 7 PIEZAS DE LA MARCA GIBSON DE ORIGEN CHINA',
#  'PAQUETE DE CHOCOLATE CON LECHE RELLENOS CON LICOR BAILEYS DE 13 PIEZAS',
#  'BOTELLA DE VIDRIO CONTENIDO CERVEZA TIPO VIENA CONT. NETO 355 ML',
#  'TAPETE DELANTERO COMPLETO PARA VEHICULOS PICKUP DE CUALQUIER MODELO MARCA LIMEA KRYSTAL MODELO 381 HECHO EN MEXICO',
#  'EN ENVASE DE VIDRIO BOTELLA DE RON BACARDI SUPERIOR  DE CONTENIDO NETO DE 980ML. CON 40% ALC. VOL. DE ORIGEN MEXICO. OSTENTA LA LEYENDA "EL ABUSO EN EL CONSUMO ES NOCIVO PARA LA SALUD"',
#  'EN ENVASE DE VIDRIO BOTELLA DE LA MARCA TORRES 5 IMPERIAL BRANDY DE ORIGEN ESPAÃ\x91A  CON CONTENIDO NETO DE 700ML  100% DE UVA CON 38% DE ALC. VOL. OSTENTA LA LEYENDA "EL ABUSO EN EL CONSUMO ES NOCIVO PARA LA SALUD"',
#  'ENVASE EN BOLSA DE PLASTICO QUE CONTIENE ARROZ SUPER ESTRA DE LA MARCA AL GRANO CON CONTENIDO NETO 900GR. IMPORTADO Y ENVASADO POR EMPACADORA LA MERCED S.A. DE C.V. CON TABLA DE INFORMACION NUTRIMENTAL CONFORME ALA NORMA',
#  'ENVASE DE VIDRIO  CONTENIDO VODKA DE LA MARCA ABSOLUT DE CONTENIDO NETO 750 ML CON 40% ALC. VOL.  PRODUCTO SUECO 100% DE GRANO EMBOTELLADO.',
#  'ENVASE DE PLASTICO CONTENIDO DETERGENTE LIQUIDO LAVATRASTES MARCA AXION CONT. NET. 750 ML  HECHO EN MEXICO PARA COLGATE PALMOLIVE  S.A. DE C.V. CON DIRECCION FISCAL  NUMERO DE LOTE Y FECHA DE CADUCIDAD DE MAYO 2017',
#  'UN PAR DE TENNIS DEPORTIVOS EN COLOR ROJO CON NEGRO DE LA MARCA NIKE  HECHO EN CHINA  IMPORTADO POR NIKE DE MEXICO S DE RL DE CV  CORTE TEXTIL  FORRO TEXTIL  SUELA HULE SINTETICA',
#  'CALZADO DEPORTIVO  COLOR NEGRA CON BLANCO MEDIDA 27 CM  CORTE TEXTIL DE FORRO TEXTIL. SUELA: HULE SINTETICA  MARCA NIKE FURY  PAIS DE ORIGEN VIETNAM  IMPORTADO POR NIKE DE MEXICO  S. DE R.L. DE C.V.',
#  'UNA MAQUINA DE PROCESAMIENTO AUTOMATICA DE DATOS PORTATIL MARCA VULCA CHALLENGER ORIGEN CHINA IMPORTADO PRO SISTEMAS INTEGRALES GAVON S DE RL DE CV CON DIRECCION FISCAL  CONSUMO DE ENERGIA  MANUAL DE USUARIO CON INFORMACION BASICA ',
#  'COMPUTADORA PROTATIL TIPO TABLETA MARCA HP STREAM 7  ORIGEN CHINA  IMPORTADO POR HEWLETT PACKARD MEXICO  S. DE R.L. DE C.V. CON DIRECCION  CON ALIMENTACION 5V FREQ N/A 2A  CON MANUAL DE INSTRUCCIONES EN IDIOMA ESPAÃ\x91OL  GARANTIA LIM',
#  'UNA BOTELLA DE VIDRIO DE BRANDY DE LA MARCA TORRES 10  100% UVA CON UN CONT. NET. 700ML  CON 38% ALC. VOL. DE ORIGEN ESPAÃ\x91OL. IMPORTADO POR BODEGA LA NEGRITA DE GUADALAJARA  S..A DE C.V.  CON DIRECCION FISCAL. CON LA LEYENDA "EL AB',
#  'BOTELLA DE VIDRIO CONTENIDO CERVEZA TIPO VIENA MARCA VICTORIA CONT. NET. 355 ML  40% ALC. VOL. POR CERVECERIA MODELO S.A. DE C.V. CON LA LEYENDA DEL ABUSO EN EL CONSUMO DE ESTE PRODUCTO NO NOCIVO PARA LA SALUD DE ORIGEN MEXICO  CON',
#  'BOTELLA DE VIDRIO CONTENIDO CERVEZA AMBAR  MARCA DOS EQUIS  CONT. NET. 325ML  4.7% ALC. VOL. HECHO EN MEXICO CON DIRECCION FISCAL  CON LEYENDA "EL ABUSO EN EL CONSUMO DE ESTE PRODUCTO ES NOCIVO PARA LA SALUD" LOTE 50724840A03220909',
#  'MANOS LIBRES  1 PIEZA COLOR BLANCO MARCA FLET MOKO  IMPORTADO POR DISTRIBUIDOR CELULAR DE LA ZONA CENTRO  S.A. DE C.V. CON DIRECCION FISCAL  ORIGEN CHINA  ENTRADA 5V SALIDA 4.5V',
#  'ENVASE DE PLASTICO CONTENIDO PROTECTOR BRILLO ORIGINAL  MARCA ARMOR ALL CONT. NET. 500ML  HECHO EN EUA  IMPORTADO VIKING ACQUISTIONS  S DE RL DE CV CON DIRECCION FISCAL  CON INSTRUCCIONES DE USO  CON LEYENDA PRECAUTORIA: NO SE DEJE',
#  'TRANSMISOR DIGITAL INALAMBRICO DE AUDIO 240 HZ  UNA PIEZA CON REPRESENTACION GRAFICA DEL PRODUCTO  MODELO AVS-900  HECHO EN CHINA  IMPORTADO POR ELECTRONICA STEREN SA DE CV CON DIRECCION FISCAL CON ESPECIFICACIONES ALIMENTARIA  LEY',
#  'ANILLO DE PLATA DE 78GR QUE TIENE GRABADAS LAS LETRAS "AG" Y #925" SEGUIDO DEL PAIS DE ORIGEN QUE ES MEXICO  CUENTA CON UN LOGOTIPO DEL IMPORTADOR',
#  'ANILLO DE ORO BLANCO DE 10 KILATES HECHO EN MEXICO DE CERTIFICACION 6V57 CON PUEDRA CIRCONIA',
#  'ARGOLLA DE ORO BLANCO E LA MARCA FONELLI HECHO EN MEXICO 14 KILATES  4.1 GRAMOS DE PESO  CERTIFICACION MF41',
#  'ANILLO DE ORO BLANCO DE 14 KILATS CON DIAMANTE DE TAMAÃ\x91O .08 MODELO 757407 MARCA ROMANZA. HECHO EN MEXICO  INFORMACION AL REVERSO DEL ANILLO  2.2 GR DE PESO  CON CERTIFICADO R757465911',
#  'ARGOLLA COMBINADA DE ORO BLANCO Y AMARILLO DE 14 KILATES  MODELO 64 DE ANCHO DE 6MM  29 GR DE PESO  HECHO EN MEXICO  REGISTRO MA-148',
#  'NO EXHIBE PRECIOS A LA VISTA  CUENTA CON INFORMACION COMERCIAL CON DEBIDA',
#  'cuenta con informacion comercial del producto',
#  'el producto verificado cuenta con fecha de caducidad vencida',
#  'OSTENTA SU INFORMACION COMERCIAL EN IDIOMA DISTINTO AL ESPAÃ\x91OL  NO CUENTA CON  FECHA DE CADUCIDAD',
#  'exhiben precio maximo al publico',
#  'cuentan con informacion comercial requerida por la norma',
#  'CUENTAN CON INFORMACION COMERCIAL LOS PRODUCTOS VERIFICADOS',
#  'CUENTA CON INFORMACION COMERCIAL DEL PRESENTE PRODUCTO',
#  'CUENTA CON INFORMACION COMERCIAL Y EXHIBEN PRECIOS CON FECHAS DE CADUCIDAD VIGENTES',
#  'CUENTA CON INFORMACION COMERCIAL DEL PRODUCTO',
#  'NO OSTENTA LA LEYENDA PRECIO MAXIMO AL PUBLICO',
#  'los productos verificados cuentan con informacion comercial y sanitaria',
#  'EL PRODUCTO VERIFICADO CUENTA CON INFORMACION COMERCIAL',
#  'CUENTA CON INFORMACION COMERCIAL APEGANDOSE AL METODO SIMPLIFICADO DE LA EVALUACION DE LA CONFORMIDAD PARA FRANJA FRONTERIZA',
#  'CUENTA CON INFORMACION COMERCIAL SE ADHIERE AL PROCEDIMIENTO SIMPLIFICADO PARA LA EVALUACION DE LA CONFORMIDAD PARA LA FRNJA FRONTERIZA',
#  'cuenta con informacion comercial',
#  'cuenta con informacion comercial en los productos verificados',
#  'CUENTA CON INFORMACION COMERCIAL',
#  'CUENTA CON INFORMACION COMERCIAL REQUERIDA POR LA PRESENTE NORMA',
#  'CUENTA CON INFORMACION COMERCIAL Y SANITARIA REQUERIDA POR LA PRESENTE NORMA',
#  'PRODUCTOS QUE CUENTAN CON LA INFORMACION COMERCIAL Y SANITARIA',
#  'CUENTA CON INFORMACION COMERCIAL Y SANITARIA',
#  'CUENTA CON INFORMACION COMERCIAL REQUERIDA POR LA NORMA',
#  'CUENTA CON INFORMACION COMERCIAL REQUERIDA POR LA NORMA',
#  'CUENTA CON INFORMACION COMERCIAL REQUERIDA POR LA NORMA',
#  'CUENTA CON INFORMACION COMERCIAL DE LA NORMA REFERIDA',
#  'PRODUCTOS QUE EXHIBEN EN SU ETIQUETADO COMERCIAL Y SANITARIA',
#  'CUENTA CON INFORMACION COMERCIAL Y SANITARIA REQUERIDA POR LA NORMA',
#  'CUMPLE CON LA NORMA DE ETIQUETADO COMERCIAL Y SANITARIO',
#  'PRODUCTOS CON INFORMACION COMERCIAL REQUERIDA POR LA NORMA',
#  'OSTAENTA CON INFORMACION COMERCIAL REQUERIDA POR LA NORMA',
#  'CUMPLE CON LA NORMA',
#  'CUENTA CON INFORMACION COMERCIAL REQUERIDA POR LA NORMA',
#  'cuenta con informacion comercial',
#  'cumple con la norma referida',
#  'CUENTA CON INFORMACION COMERCIAL REQUERIDA PRO LA PREASENETE NORMA',
#  'CUNETA CON INFORMACION COMERCIAL REQUERIDA POR LA NORMA',
#  'CUENTA CON INFORMACION COMERCIAL REQUERIDA POR LA NORMA',
#  'productos que cuentan con fecha de caducidad vencida',
#  'no cuenta con lista de ingredientes en el menu a lo cual tiene un costo mismo que no cuwenta con dicha lista',
#  'CUENTA CON INFORMACION COMERCIAL',
#  'PRODUCTO CON INFORMACION COMERCIAL',
#  'OSTENTA INFORMACION COMERCIAL EN IDIOMA DISTINTO AL ESPAÃ\x91OL EN SUS INSTRUCCIONES DE CUIDADO Y NO CONTENER DATOS DEL IMPORTADOR EN CUANTO A NOMBRE RAZON SOCIAL Y  DOMICILIO',
#  'LOS PRODUCTOS NO INDICAN LOS DATOS DEL FABRICANTE O IMPORTADOR YA QUE LA INFORMACION SE OSTENTA EN IDIOMA DISTINTO AL ESPAÃ\x91OL',
#  'cuenta con informacion comercial requerida por la norma',
#  'cuenta con informacion comercial requerida por la norma',
#  'cuenta con datos de la informacion comercial en idioma distinto al espaÃ²ol',
#  'los productos verificados exhiben en su etiqueta los datos de l importador asi como su informacion comercial apegandose a la evaluacion de la conformidad para franjas fronterizas',
#  'ostenta con informacion comercial',
#  'cuenta con informacion comercial',
#  'los productos de las marcas great value  aunt hatties  natures own',
#  'productos de las marcas first street ragu y or ville cuentan con informacion comercial en idioma distinto al espaÃ²ol',
#  'PRODUCTOS QUE OSTENTAN SU INFORMACION COMERCIAL EN IDIOMA DISTINTO AL ESPAÃ\x91OL Y NO EXHIBEN PRECIOS A LA VISTA',
#  'TRU MOO  SNO FINE   CUMPLE CON LA NOM',
#  'DOLORES AGUA /ACEITE CUMPLE CON LA NOM',
#  'RAGU  SMUCKERS  DUNCAN  OLD ORCHARD  OROWEAT DICHAS MARCAS CUENTAN CON INFORMACION REQUERIDA POR LA NORMA.',
#  'CUMPLE CON LA MORMA.',
#  'CUMPLE CON LA NORMA .',
#  'INFORMACION COMERCIAL EN IDIOMA DISTINTO AL ESPAÃ\x91OL',
#  'LOS PRODUCTOS CUENTAN CON SU INFORMACION COMERCIAL EN IDIOMA DISTINTO AL ESPAÃ\x91OL NO CONTANDO CON MODULO DE INFORMACION',
#  'L.A CETTO  VINO TINTO   CUMPLE CON LA NORMA.',
#  'CUENTA CON INFORMACION COMERCIAL',
#  'WESTERN GRILLERS  VITA BITE  DIXIE  FOOD SERVICE  WILSEY   PRODUCTOS QUE CUMPLEN CON LA NOM.',
#  'HELLMANNS  COCA COLA LIGHT  MARUCHAN  CRISTAL   NUTRI LECHE.PRODUCTOS QUE CUMPLEN CON LA NORMA.',
#  'FECHA DE CADUCIDAD VENCIDA',
#  'PRODUCTOS QUE CUENTAN CON FECHA DE CADUCIDAD VENCIDA Y NO EXHIBEN PRECIOS A LA VISTA',
#  'cuenta con informacion comercial y sanitaria',
#  'cuenta con informacion comercial y sanitarai asi como el importador es distribuidora e importadora alsea s.a. de c.v.av. tlahuac numero 6708 colonia santiago zapotitlan deleg tlahuac mexico d.f.',
#  'cuentan con la informacion comercial referida por la norma',
#  'cuenta con informacion comercial requerida por la norma',
#  'cuenta con informacion comercial requerida por la norma',
#  'cuenta con informacion comercial requerida por la norma',
#  'cuenta con informacion comercial y sanitaria requerida por la norma condicionando la propina en el documento una vez quese cobro el monto de la cuenta',
#  'informacion comercial en idioma distinto al espaÃ²ol',
#  'los productos verificados cuentan con fecha de caducidad vencida',
#  'prodcutos que cuentan con infornmacion comercial requerida por la norma',
#  'LOS PRODUCTOS VERIFICADOS NO EXHIBEN PRECIOS Y  CON FECHA DE CADUCIDAD VENCIDAD',
#  'CUMPLE CON LA NORMA',
#  'CUMPLE CON LA NORMA',
#  'no cumple con la norma',
#  'cumple con la norma',
#  'cumple con la norma',
#  'cuenta con informacion comercial requerida por la presente norma',
#  'cuenta con informacion comercial requerido por la norma',
#  'productos con fecha de caducidad vencida y sin precios a la vista del consumidor',
#  'informacion que incumple con la norma asi como la fecha de caducidad y no exhiben precios',
#  'cuenta con fecha de caducidad vencidad y no exhibe precios',
#  'productos con fecha de caducidad venciday no exhibe precios',
#  'cuenta con informacion comercial y sanitaria',
#  'informacion comercial en idioma distinto al espaÃ²ol',
#  'no entrega comprobantes',
#  'productos de las marcas rosseh stover  marinela y megaball que cuentan con fecha de caducidad vencida asi como no exhibir precios',
#  'cuenta con informacion comercial requerida por la presente norma',
#  'CUENTA CON INFORMACION COMERCIAL REQUERIDA POR LA PRESENTE NORMA',
#  'PRODUCTOS CON INFORMACION COMERCIAL',
#  'LOS PRODUCTOS DESCRITOS DE LAS MARCAS RICOLINO ANGELITOS LA INDIA VERDEÃ\x91A DÃ¯GARI CUENTAN EN SU ETIQUETADO COMERCIAL CON LA FECHA DE CADUCIDAD VENCIDA',
#  'CUENTA CON INFORMACION COMERCIAL Y SANITARIA PARA LA PRESENTE NORMA',
#  'CUENTA CON INFORMACIONCOMERCIAL Y SANITARIA DE LA PRESENTE NORMA',
#  'CUENTA  CON INFORMACION COMERCIAL Y SANITARIA',
#  'CUENTA CON INFORMACION COMERCIAL Y SANITARIA REQUERIDA POR LA NORMA',
#  'CUENTA CON INFORMACION COMERCIAL REQUERIDA POR LA PRESENTE NORMA',
#  'CUENTA CON INFORMACION COMERCIAL PARA ESTA NORMA',
#  'CUENTAN LOS PRODUCTOS VERIFICADOS CON LA INFORMACION COMERCIAL DISTINTA AL ESPAÃ\x91OL NO APLICA MODULO DE INFORMACION PARA EL METODO SIMPLIFICADO',
#  'cuentan con informacion comercial y sanitaria',
#  'cuenta con informacion comercial y sanitaria',
#  'los productos verificados no exhiben precios a la vista del consumidor asi como un total de 8 cuentan con fecha de caducidad vencida',
#  'productos con informacion comercial',
#  'productos que cuentan con informacion comercial requerida por la presente norma',
#  'si exhibe el precio maximo al publico',
#  'los productos verificados cuentan con informacion comercial en su etiquetado',
#  'los productos de las marcas golden grill  heinz full red  california grill  chefs quality no ostenta en su etiquetado con la fecha de caducidad informacion que ostenta en idioma distinta en espaÃ²ol',
#  'los productos de las marcas maseca  french  kellogs  lala  jersey  bimbo gansito no exhiben precios a la vista',
#  ' cuenta con informacion comercial',
#  'productos caductos no exhiben precios',
#  'cuenta con fecha de caducidad vencidad',
#  'CUENTA CON  INFORMACION COMERCIAL Y SANITARIA',
#  'CUENTA CON INFORMACION  COMERCIAL REQUERIDA POR LA PRESENTE NORMA',
#  'CUENTA CON INFORMACION COMERCIAL EN EL ETIQUETADO',
#  'CUENTA CON INFORMACION COMERCIAL Y REQUERIDA POR LA NORMA',
#  'OSTENTA INFORMACION COMERCIAL EN SU ETIQUETADO',
#  'CUENTA XCON INFORMACION COMERCIAL Y SANITARIA',
#  'cuentan con informacion comercial de etiquetado',
#  'cuenta con informacion comercial requerido por la norma',
#  'productos que cuentan con informacion comercial',
#  'no ostenta con logotipo ni pais de origen',
#  'no exhibe en el producto el pais de origen ni el lgotipo',
#  'LOS PRODUCTOS DE LAS MARCAS CELLET  STRONGER  BUFF CUENTAN CON SU INFORMACION COMERCIAL EN IDIOMA DISTINTO AL ESPAÃ\x91OL',
#  'los productos que comercializa no ostentan con el pais de origen ni logotipo',
#  'no cuenta con el pais de origen',
#  'CUENTAN CON INFORMACION COMERCIAL REQUERIDA POR LA NORMA',
#  'no cuenta con informacion comercial ni en el modulo de informacion',
#  'productos de las marcas la morena  fresca  alpezzi  knorr  salsa corita y chilimon que cuentan con fecha de caducidad vencida asi como no contar con fecha de caducidad  las marcas corita y chilimon',
#  'NO CUENTA CON INFORMACION COMERCIAL REQUERIDA POR LA NORMA',
#  'LOS PRODUCTOS VERIFICADOS CUENTAN CON INFORMACION COMERCIAL CONFORME A LA NORMA',
#  'cuenta con informacion comercial  entrega comprobantes y exhibe precios',
#  'productos que ostentan fecha de caducidad vencida',
#  'cuenta con informacion comercial entrega comprobantes y exhibe precios a la vista',
#  'cuenta con informacion comercial exhibe precio y entrega comprobante',
#  'los productos verificados exhiben precios y cuentan con informacion comercial',
#  ' LOS PRODUCTOS VERIFICADOS NO EXHIBEN MARCA   PRESENTACION NI FECHA DE CADUCIDAD',
#  'CUENTAN CON INFORMACION COMERCIAL',
#  'no ostenta fecha de caducidad en el etiquetado',
#  'los productos verificados cuentan con fecha de caducidad vencidad e informacion comercial descrita en el producto',
#  'cuenta con informacion comercial',
#  'los productos verificados no ostentan grabado el 0.925 de la denominacion de plata asi como el pais de origen',
#  'cuenta con informacion comercial requerida por la norma',
#  'cuenta con informacion comercial requerida por la norma',
#  'CUENTA CON INFORMACION COMERCIAL REQUQERIDA POR LA NORMA',
#  'CUENTA CON INFORMACION COMERCIAL',
#  'CUENTA CON INFORMACION COMERCIAL REQUERIDO POR LA PRESENTE NORMA',
#  'CUENTA CON INFORMACION COMERCIAL REQUERIDA POR LA NORMA',
#  'cuenta con informacion comercial de la norma presente',
#  'LOS PRODUCTOS CUMPLEN CON LA NOM',
#  'NO OSTENTA PAIS DE ORIGEN NI FABRICANTE O IMPORTADOR',
#  ' ETIQUETADO EN IDIOMA DIFERENTE AL ESPAÃ\x91OL',
#  'OSTENTAN INFORMACIÃ\xa0N EN IDIOMA DIFERENTE AL ESPAÃ\x91OL',
#  "nectar de mango del valle de 200ml  mostaza mccormick de 210g  salsa de tomarte heinz 397g  pure de tomate condimentado marca del fuerte de 210g  aderezo de mayonesa hellman's de 390g",
#  'aderezo para ensalada cesar marca clemente jacques de 237 ml  aderezo de mayonesa marca mc cormick de 350g  mayonesa marca mccormick de 285g  cebolla picada marca herdez de 210g  salsa casera marca herdez de 453g ',
#  'pan blanco bimbo de 460g pure de tomate del fuerte de 345g  mayonesa marca best foods real de 473ml  mermelada de fresa marca mc cormick de 270g salsa de tomate marca heinz de 397g',
#  'mostaza marca mccormick de 210g  media crema lala de 200ml  sopa crema marca campbell de 300g  salsa verde marca herdez de 210g  jugo zazonador marca maggi de 100ml  mole doÃ²a maria herdez de 540g  bebida sabor naranja marca nestle',
#  'mayonesa best foods 473ml pure de tomate condimentado marca del marques 210g  rajas de chile jalapeÃ²os en escabeche la costeÃ²a de 220g  jugo sazonador maggi de 100 ml.',
#  "salsa de tomate marca ketchup de 397g  lomo de atun aleta amarilla en agua marca dolores de 85g  aderezo para ensaladas estilo cesar marca clemente jacques de 237ml  sopa crema de champiÃ²ones marca campbell's de 300g  frijoles char",
#  'chocolates de las siguientes marcas:larin de 10 piezas  la corona de 20 piezas  carlos v de 18 piezas  tikys de 70 piezas',
#  'chocolates de la marca michel de 30 piezas  de la rosa de 12 piezas  breme de 150g  ricolino de 18 pÂ¡ezas ',
#  'chocolate con leche marca snickers  chocolate con leche con leche milkyway  dulce de chocolate marca gourmet  chispas de chocolate marca chocomey   bombones de chocolate marca ancer',
#  'chocolate con leche y almendras marca kisses de 900g  chocolate con leche marca kisses de 900g  chocolate con leche marca snickers de 52.7g  chocolate con leche marca kisses de 160g  chocolate con leche marca kisses 44g',
#  'malvavisco cubierta sabor chocolate dulces vero de 60 piezas  chocolate con leche mckinb de 23g  chocolate con leche turin de 70g  chocolate con leche turin de 4 piezas ',
#  'chocolate con leche marca tres mosqueteros de 326g  chocolate con leche marca milkyway de 442g  nougat cubierto de chocolate marca de la rosa de 56g  chocolate con leche marca carlos v de 22g  chocolate con leche marca milkyway de',
#  'chocolate con leche marca dove de 244.8g  chocolate relleno caramelo marca milkyway de 313.8g chocolate con relleno de caramelo marca snickers de 316.2g  huevitos sabor chocolate concentrado marca la corona de 500g  chocolate con l',
#  'pure de tomate del fuerte de 210g  rajas de chiles jalapeÃ²os marca la costeÃ²a de 121g  pan dulce bimbo de 135g  pan harina de trigo marca bimbo de 680g',
#  'mayonesa marca mccormick de 285g  pure de tomate del fuerte de 210g  mole doÃ²a maria de 235g  mayonesa best foods de 473ml  agua bonafont de 1.5 litros',
#  'nectar de durazno jumex de 1 litro  mole listo para servir doÃ²a maria de 540g  mayonesa mccormick de 285g  elote dorado la costeÃ²a de 220g  salsa de tomate ketchup de 397g',
#  'mayonesa mccormick de 285g  nectar de durazno jumex de 200ml  media crema nestle de 225g  frijoles refritos la sierra de 440g',
#  'jugo de tomate con un toque de almejaa clamato de 946ml  salsa picante huichol de 190ml  mostaza mccormick de 210g  frijoles bayos refritos la costeÃ²a de 440g  eaderezo para ensalada estilo cesar clemente jaques de 237ml  pure de t',
#  "nectar de manzana jumex de 500ml  chiles en raja costeÃ²a de 220g  ensalada de verduras la costeÃ²a de 220g  elote grano del marques de 430g  salsa de tomate hunt's de 195g mayonesa kraft de 145g",
#  "mermelada de fresa smucker's de 297g  agua ligera con jugo de uva bonafont de 300ml  dulce de leche la lechera de 325g  crema de avellanas tods de 350g  cafe con leche lala de 1 litro",
#  "chocolate con leche marca hersheys de 6 piezas  chocolate con avellanas ferrero rocher de 200g  chocolate con leche tiky's de 2823g  chocolate con leche kisses de 850g",
#  'malvavisco cubierto con chocolate de la rosa de 24 piezas  paleta de malvavisco cubierta de chocolate la corona de 18 piezas  golosina sabor a chocolate  cs de 50 piezas',
#  'salsa verde herdez de 210g  pure de tomate del fuerte de 345g  pure de papa instantaneo verde valle de 160g  chiles jalapeÃ²os en escabeche la costeÃ²a de 380g ',
#  'tostadas de maiz nixtamalizadas marca tostitos de 200g  chile chipotle marca la costeÃ²a de 105g  ensalada de verduras marca del marques de 225g  pure de tomate marca del fuerte de 210g  pan de harina de trigo integral marca bimbo d',
#  'harina para hot cakes marca pronto 350g  mole listo para servir marca doÃ²a maria de 540g  salsa casera marca herdez de 210g  frijoles refritos chata de 430g.',
#  'chocolate de la diferentes marcas como son: carlos v de 18 piezas  milky way de 313g  huevitos de 500g  kisses de 900g  chocovick de 600g',
#  'bombon cubierto de chocolate la corona de 104g  chocolate con leche 234g marca m&m  chocolate con leche milkyway de 468g  chocolate con leche snickers de 468g  chocolate con leche dole de 128g',
#  'dulce con sabor a chocolate con leche marca palmer lima  paleta de malvavisco cubierta de chocolate marca de la rosa y paleta de malvavisco  cubierta de chocolate marca michel de 10 piezas',
#  'paleta de malvavisco cubierta de chocolate marca paleton de 18 piezas  galleta con crema de cacahuate y cobertura sabor chocolate marca bocadin de 50 piezas  chocolate con leche confitado con cacahuate  marca m&m de 6 piezas.',
#  'MARCA NUGS DE 6 PIEZAS  NUGS DE 12 PIEZAS  DE LA ROSA DE 50 PIEZAS CHOCOMEX DE 500G  HEAVENLY HEARTS DE 1 KG',
#  'plancha t-fal  de indonesia  reproductor de c.d. marca philips licuadora phillo de mÂ¿xico  licuadora oster de mÂ¿xico  cafetera t-fal de china',
#  'GUAYABERA MARCA COSTA BRAVA  SACO PARA DAMA MARCA OTRO CAPRICHO  CAMISA DE VESTIR  MARCA SENATOR  CAMISA BLANCA PETIT ECOLER  CAMISA PARA DAMA CIAO BELLA',
#  'MULTIPROCESADOR DE ALIMENTOS MARCA RECARD  EXPRIMIDOR DE CITRICOS ELECTRICO DE 1 LITRO MARCA PROCTOR SILEX  PARRILLA ELECTRICA TAURUS EXTRACTOR DE JUGOS USO RUDO MARCA TURMIX HORNILLO ELECTRICO DE COCCION MARCA JETFRYER',
#  'TELEVISION LED DE 32 PULGADAS SMARTV MARCA LG  LICUADORA 10 VELOCIDADES MARCA OSTER  HORNO DE MICROONDAS DE 1.1 PIES MARCA WHIRLPOOL REFRIGERADOR 10 PIES MARCA MABE ESTUFA 30 PULGADAS',
#  'TOSTADOR DE PAN MARCA OSTER  CAFETERA MARCA TAURUS PANTALLA 70 PULGADAS MARCA SHARPP  ESTEREO DE DISCO COMPACTO MARCA PANASONIC  EXTRACTOR Y EXPRIMIDOR DE JUGOS MARCA TURMIX',
#  'HUARACHE PARA DAMA MARCA LUNA LIQUIDA SANDALIA PARA DAMA MARCA INSTINTO HUARACHE MARCA INSTINTO  SANDALIA PARA DAMA MARCA LUNA LIQUIDA TENIS PARA CABALLERO MARCA ZAKKE',
#  'ZAPATO PARA NIÃ\x91O MARCA CHABELO  ZAPATO DE CONFORT MARCA CLINTON  ZAPATO ESCOLAR MARCA ELEFANTE ZAPATO PARA CABALLERO MARCA FLEXI',
#  "TENIS PARA DAMA MARCA NIKE  TENIS PARA CABALLERO MARCA FILA  TENIS PARA CABALLERO DC TENIS PARA NIÃ\x91A MARCA SKECHER'S  TENIS PARA CABALLERO MARCA REEBOK",
#  'HARINA PARA PREPARAR PANQUESITOS MARCA PILLSBURY DE 432G  HARINA PARA PREPARAR PASTEL MARCA PILLSBURY DE 432G',
#  'CHOCOLATE DE LECHE MARCA CARLOS V 32 PIEZAS CHOLATE CON LECHE MARCA AMOR DE 64G  CHOCOLATE DE LECHE MARCA CHOKOBALLS DE 1 KG  CHOCOLATE DE LECHE MARCA KISSES DE 311G  CHOCOLATE CON LECHE MARCA M&M DE 295.8G ',
#  'CAFETERA TFAL MODELO CM2208MX TOSTADOR MOULINEX MODELO TT110252  TOSTADOR KRUPS MODELO KH732D50 BATIDORA MOULINEX MODELO DD100M1ME TOSTADOR DEPAN LEONIX TAURUS MODELO LEONIX',
#  "ENSALADA DE VERDURA LA COSTEÃ\x91A DE 220G MAYONESA HELLMANN'S DE 390G  PURE DE TOMATE DEL FUERTE DE 210G CHILES RAJAS LA COSTEÃ\x91A DE 380G CHILORIO CHATA DE 170G NECTAR DE MANGO DEL VALLE DE 413 ML ",
#  'CREMA LALA DE 200ML  PURE DE TOMATE CONDIMENTADO DEL FUERTE DE 210G  SALSA DE CHILE FRESCO EL PATO DE 225G  SALSA CASERA HERDEZ DE 240G  PASTELITO RELLENO CUBIERTO CON GLASS SABOR CHOCOLATE MARINELA DE 120G  ADEREZO DE MAYONESA HEL',
#  'NEVTAR DE MANGO MARCA DEL VALLE DE 20ML  MERMELADA DE FRESA  MARCA MCCORMICK DE 270G  MEDIA CREMA MARCA NESTLE DE 225G  CACAHUATE ESTILO JAPONES MARCA SABRITAS DE 100G  SALSA DE CHILE FRESCO MARCA DEL PATO DE 225G  HARINA PREPARADA',
#  "RON CAPTAIN MORGAN DE 750ML  VODKA SMIRNOFF DE 1 LITRO  WHISKY BUCAHNAN'S DE 750ML  BRANDY FUNDADOR DE 700ML  RON HAVANA CLUB DE 750ML  GINEBRA TANQ ERAY DE 750ML WHISKY JOHNNIE WALKER DE 750ML ",
#  'vodka oso negro de 1.75ml   whisky johnnie walker de 750ml cognac pour voiser de 700ml whisky chivas regal de 750ml  vodka absolut de 750ml ',
#  "whisky johnnie walker etiqueta negra de 750ml whisky buchanan's de 750ml  whisky jack daniel's de 700ml  vodka smirnoff de 1 litro  vodka absolut de 750ml ",
#  "buchanan's de 750ml jack daniels de 700ml  sterling de 750 ml  smirnoff de 1 litro  oso negro de litro",
#  'vodka absolut de 750ml  vodka smirnoff de un litro  whisky jhonnie walker de 750ml ron blanco bacardi de 980ml  ron aÃ²ejo bacardi de 1 litro',
#  'cereal de trigo inflado y endulzado sabor a vainilla marca chachitos de 250g  cereal de trigo inflado y endulzado sabor a vainilla marca chachitos de 500g  cereal de trigo inflado y endulzado sabor vainilla marca tikiss de 250g.',
#  'chocolate con leche marca dove de 6 barras  chocolate con leche relleno con almendras marca mont blanc de 104g  chocolate con leche marca carlos v de 16 piezas malvavisco cubierto con chocolate marca drums de 24 piezas',
#  'atun en agua marca el dorado de 140g  atun en aceite marca nair de 140g  atun en aceite marca el dorado de 140g  atun en agua marca mazatun de 140g  atun en aceite marca herdez de 130g',
#  'atun aleta amarilla en agua  marca marinero de 140g fabricado por incortec s.a. de c.v.  atun aleta amarilla en agua con aceite marca marinero de 140g  fabricado por incortec s.a. de c.v.',
#  'atun aleta amarailla en aceite marca el dorado de 140g  atun aleta amarilla en agua marca nair de 130g  lomo de atun aleta amarilla en agua  marca dolores de 140g lomo de atun aleta amarilla en agua marca mazatun de 140g  atun alet',
#  'lomo de atun aleta amarilla en aceite marca tuny de 140g  lomo de atun aleta amarilla en aceite marca dolores de 140g  lomo de atun aleta amarilla en aceite marca mazatun de 140g  lomo de atun aleta amarilla en agua marca mazatun',
#  'atun en aceite dolores de 1880kg  atun en agua marca dolores de 1880kg  atun en agua marca tuny de 140g  atun en agua marca mazatun de 140g  atun en agua marca herdez de 130g ',
#  'lomo de atun aleta amarilla en agua marca mazatun de 140g  lomo de atun aleta amarilla en aceite marca mazatun de 140g  lomo de atun aleta amarilla en aceite marca dolores de 140g  lomo de atun aleta amarilla en aceite marca herdez',
#  'atun en agua marca soriana de 140g  lomo de atun aleta amarilla marca maztun de 140g  atun aleta amarilla en aceite marca el dorado de 140g  lomo de atun aleta amarilla en aceite marca dolores de 140g  lomo de atun aleta amarilla e',
#  'lomo de atun aleta amarilla marca tuny de 1409g  lomo de atun aleta amarilla en agua marca herdez de 130g  atun aleta amarilla en agua marca aurrera de 140g  lomo de atun aleta amarilla en agua marca mazatun de 140g  lomo de atun a',
#  'lomo de atun aleta amarilla en agua marca marina azul de 74g  lomo de atun aleta amarilla en agua marca bakers & chefs de 1.881g  lomo de atun aleta amarilla en aceite marca tuny clasico de 140g  lomo de atun aleta amarilla en agua',
#  'atun aleta amarilla en agua marca el dorado de 140g  lomo de atun aleta amarilla en aceite marca herdez de 130g  lomo de atun aleta amarilla marca dolores de 140g  lomo de atun aleta amarilla en aceite marca tuny de 140g  atun alet',
#  'lomo de atun aleta amarilla en aceite marca mazatun de 295g  lomo de atun aleta amarilla en aceite marca tuny de 140g  lomo de atun aleta amarilla en agua marca mazatun de 295g  atun aleta amarilla marca el dorado de 140g',
#  'atun aleta amarilla en aceite marca nair de 130g  atun aleta amarilla en agua marca nair de 130g  lomo de atun aleta amarilla en agua marca dolores de 140g  lomo de atun aleta amarilla en aceite marca dolores de 140g atun aleta ama',
#  'atun aleta amarilla en aceite marca chedraui de 140g  atun aleta amarilla en aceite marca ancla de 140g lomo de atun aleta amarilla en agua marca mazatun de 140g  atun aleta amarilla en agua marca el dorado de 140g  atun aleta amar',
#  'lomo de atun marca marino de 140g lomo de atun marca dolores de 140g atun marca aurrera de 140g  atun marca herdez de 130g  atun marca tuny',
#  'atun marca ancla de 140g  atun marca ley de 140g  atun marca nair de 130g  atun tuny de 140g  atun marca bomarin de 140g ',
#  'lomo de atun aleta amarilla en agua marca mazatun de 140g  lomo de atun aleta amarilla en aceite marca herdez de 130g  atun aleta amarilla en aceite en hojuelas marca soriana de 140g  lomo de atun aleta amarilla en aceite marca dol',
#  'atun aleta amarilla en agua marca marinero de 140g  atun aleta amarilla en agua con aceite marca marinero de 140g',
#  'ATUN ALETA AMARILLA MARCA TUNY DE 140G LOMO DE ATUN EN AGUA MARCA DOLORES DE 140G  ATUN ALETA AMARILLA MARCA NAIR DE 140G  ATUN ALETA AMARILLA MARCA EL DORADO DE 140G  LOMO DE ATUN ACEITE MARCA MAZATUN DE 140G  ATUN ALETA AMARILLA',
#  'ATUN ALETA AMARILLA MARCA CORINA DE 140G  ATUN ALETA AMARILLA MARCA ANCLA DE 140G  ATUN ALETA AMARILLA MARCA NAIR DE 140G  LOMO DE ATUN EN AGUA MARCA HERDEZ DE 130G LOMO DE ATUN EN ACEITE MARCA DOLORES DE 140G  LOMO DE ATUN ALETA A',
#  'LOMO DE ATUN ALETA AMARILLA EN ACEITE MARCA MAZATUN DE 140G  LOMO DE ATUN ALETA AMARILLA EN ACEITE MARCA DOLORES DE 140G  LOMO DE ATUN ALETA AMARILLA EN ACEITE MARCA TUNY DE 140G  ATUN ALETA AMARILLA EN AGUA MARCA BONATUN DE 140G',
#  'lomo de atun aleta amarilla en aceite marca herdez de 130g  atun aleta amarilla en agua marca calmex de 140g  lomo de atun aleta amarilla en agua marca tuny de 140g  atun aleta amarilla en agua marca chedraui de 140g',
#  'atun aleta amarilla en agua marca ley de 140g  atun aleta amarilla en agua marca nair de 130g  atun aleta amarilla en agua con aceite marca bonatun de 140g  lomo de atun aleta amarilla en aceite marca mazatun de 140g',
#  'blusa para dama marca fashion wep  blusa para dama marca made for met look amazing',
#  'agua de perfume marca purzs de 50ml  agua de tocador marca looney tunes de 100ml  perfumen woman marca nike perfume  de 785ml  agua de tocador marca nike basic de 75ml  agua de tocador marca b.f.c. de 100ml  agua de tocador marca t',
#  'cacahuate japones marca sabritas de 53g  ensalada de verduras marca la costeÃ²a de 220g  galleta con relleno de fresa marca maravilla de 67g  frituras de maiz nixtamalizado marca fritos de 60g  pan dulce de 43g',
#  'pure de tomate marca del fuerte de 210g  galleta fortificada marca gamesa de 170g  tortilla de maiz enrollada frita marca barcel de 62g  pan dulce marca bimbo de 62g  cacahuate japones marca karate de 60g ',
#  'galleta fortificada marca maria gamesa de 170g  barra de granola y arroz infladomarca ritz de 31g  cacahuate estilo japones marca sabritas de 10g  totopos de maiz nixtamilizado sabor queso y chile marca tostitos de 65g ',
#  'salsa marisquera marca 7 mares de 150g  salsa picante marca huichol de 190ml  salsa de tomate marca del monte de 390g  chiles jalapeÃ²os en escabeche marca la costeÃ²a de 220g vegetales mixtos marca veg-all de 425g',
#  'caldillo tomate rojo marca knorr de 250g  mermelada de piÃ²a marca del monte de 270g  jugo nectqar de naranja  marca jumex de 500mlleche parcialmente descremada condensada marca nestle de 397g  salsa casera marca herdez de 210g',
#  'pure de tomate condimentado marca del fuerte de 343g  salsa casera marca herdez de 210g  ensalada de verduras marca del marques de 215g  mole doÃ²a maria de 235g  salsa picante marca la guacamaya tradicional de 365ml',
#  'lubricante en aerosol marca truper de 275ml  pegamento y sellador marca pega duro de 1litro color para cemento marca cemix de 1 kg  sellador uso general marca truper de 280ml  cepillo para pintor marca truper de 1 pieza.',
#  'toallas para trabajo pesado marca scott de 55 piezas  pinza ponchadura marca argos de 1 pieza  pinzas para pelar cables coaxial marca peal de 1 pieza.',
#  'pantalon marca boom boom jeans  saco vestido vestido falda',
#  'armazon de las siguientyes marcas:irais fashion eyewar  polo star dublin eye wear r&b polo star  lander',
#  'salsa pÂ¡cante marca valentina de 370ml  chamoy marca dulces rossy de 1/2litro  coctel de tomate con almeja marca pacific mix clam de 1 litro dulce de guayaba marca la paloma de 60g',
#  'liston para regalo marca ribocel de 50metros  liston decorativo marca celosa de 41.4metros  moÃ²o gigante marca ribomatik de 50 piezas  globo de  nieve marca hello kitty de 1 piezas  caja de recuerdos marca hello kitty de 20 piezas',
#  "conjunto marca mam'san de 200g unguento marca aranda de 100g unguento marca de la tia de 125g  unguento marca zoosarni de 200g  pomada marca bruovel de 250g",
#  'aislante cinta marca itella de 1 pieza  silicon formados de juntas marca versa chem de 85g  cinta aislante de vinil marca 3m de un rollo ',
#  'jugo de tomate marca clamato de 473ml  chamoy marca rossy 500ml  leche evaporada marca nestle de 360g  salsa picante marca valentina  salsa picante marca huichol de 190ml ',
# ...
#  'SE VERIFICA UNA BASCULA CON NUMERO DE SERIE I13099064 LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA PERMITIDA',
#  'SE VERIFICO UNA BASCULA DE LA MARCA BAMEX SIN NUMERO DE SERIE LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'SE VERIFICA UNA BASCULA MARCA NOVAL SIN NUMERO DE SERIE LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA PERMITIDA',
#  'SE VERIFICA UNA BASCULA CON NUMERO DE SERIE 1066 LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'SE VERIFICA UNA BASCULA MARCA ESHER CON NUMERO DE S3ERIE 3841 LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'SE VERIFICA 1 BASCULA MARCA NOVAL CON NUMERO DE SERIE A LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'SE VERIFICO UNA BASCULA CON NUMERO DE SERIE 17X LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'SE VERIFICO UNA BASCULA MARCA JACOBS DETECTO SIN NUMERO DE SERIE LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'SE VERIFICO UNA BASCULA CON NUMERO DE SERIE 16358 LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'LOS PRODUCTOS FERIFICADOS TENIAN DOS ETIQUETAS',
#  'SE VERIFICO UNA BASCULA CON NUMERO DE SERIE 127253 LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'SE VERIFICA UNA BASCULA MARCA THOR CON NUMERO DE SERIE 61476 LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'SE VERIFICA UNA BASCULA CON NUMERO DE SERIE 38940 LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'SE VERIFICA UNA BASCULA MARCA DYFSA CON NUMERO DE SERIE 860 LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'SE VERIFICO UNA BASCULA SIN MARCA Y SIN NUMERO DE SERIE LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'SE VERIFICO UNA BASCULA CON NUMERO DE SERIE C126032 LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'SE VERIFICA UNA BASCULA CON NUMERO DE SERIE 2265 LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'se verifica una bascula marca noval sin numero de serie la cual se encontro dentro de la tolerancia',
#  'se verifican 2 basculas uno marca warner sin numero de serie y el segundo marca hm sin numero de serie los cuales se encontraron dentro de la tolerancia permitida',
#  'se verifica una bascula con numero de serie 9167 la cual se encontro dentro de la tolerancia',
#  'SE VERIFICO UNA BASCULA MARCA OKEN CON NIMERO DE SERIE 60796 LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'SE VERIFICA UNA BASCULA MARCA OKEN CON NUMERO DE SERIE 44415 LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'SE VERIFICA UNA BASCULA MARCA TAURO SIN NUMERO DE SERIE LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'SE VERIFICA UNA BASCULA HM SIN NUKMERO DE SERIE LA CUAL SE ENCUENTRA DENTRO DE LA TOLERANCIA',
#  'SE VERIFICO UNA BASCULA CON NUMERO DE SERIE 926 LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'SE VERIFICA UNA BASCULA MARCA REGO CON NUMERO DE SERIE 4095 LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'SE VERIFICA UNA BASCULA MENHER CON NUMERO DE SERIE 446 LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'SE VERIFICO UNA BASCULA MARCA AUGUST SAUTER CON NUMERO DE SERIE 506576 LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'SE VERIFICO UNA BASCULA MARCA AUGUST SAUTER CON NUMERO DE SERIE 513131 LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'SE VERIFICO UNA BASCULA CON NUMERO DE SERIE F0998975 LA CUAL SE ENCONTRO DENTRO DE LA TOLERANCIA',
#  'NO SE DETECTO INCUMPLIMIENTO',
#  'NO SE DETECTO INCUMPLIMIENTO',
#  'NO SE DETCTO INCUMPLIMIENTO',
#  'NO SE DETECTO INCUMPLIMIENTO',
#  'NO SE DETECTO INCUMPLIMIENTO',
#  '     CUMPLE CON LA NORMA',
#  ' CUMPLE CON LA NORMA',
#  '  CUMPLE CON LA NORMA',
#  '  CUMPLE CON LA NORMA',
#  'NO EXHIBE POR ALGUN MEDIO O FORMA LA EQUIVALENCIA DE KILATES A MILESIMAS',
#  'NO SE DETECTO INCUMPLIMIENTO',
#  '   CUMPLE CON LA NORMA',
#  ' CUMPLE CON LA NORMA',
#  '    NO SE DETECTO INCUMPLIMIENTO',
#  'CUMPLE CON LA NORMA',
#  ' NO SE DETECTO INCUMPLIMIENTO',
#  '    NO SE DETECTO I NCUMPLIMIENTO',
#  '   NO SE DETECTO INCUMPLÃ\x91IMIENTO',
#  'CUMPLE COMPLE CON LA NORMA',
#  'SE VERIFICO FIGURA CON PROYECTIL DE LA MARCA MATTEL  AUTO CONVERTIBLE DE LA MARCA MATTEL Y  MUÃ\x91ECA MI PRIMERA BEBE DE LA MARCA FISHERDICCE.',
#  'SE VERIFICO SUPER HEROE DE GRAN TAMAÃ\x91O DE LA MARCA HASBRO  BARBIE CON ACCESORIO DE LA MARCA  MATTEL Y FIGURA CON 4 PROYECTILES DE LA MARCA MATTEL.',
#  'SE VERIFICO MUÃ\x91ECO MI PRIMER OSITO DE LA MARCA MATTEL  MUÃ\x91ECA Y PONY  MUÃ\x91ECO TORTUGA NINJA  DE LA MARCA SPIN MASTER.',
#  'SE VERIFICO CLUB HELLO KITY CAFE IMPORTADO POR JUGUETES FAMISA S.A. DE C.V.',
#  'SE VERIFICO SANDALIAS BLANCAS PARA NIÃ\x91AS DIFERENTES NUMEROS DE LA MARCA  MINI BURBUJAS Y CALZADO BLANCO PARA NIÃ\x91AS DIFERENTES NUMEROS DE LA MARCA COQUETA.',
#  'SE VERIFICO MUÃ\x91ECA BARBIE DE LA MARCA MATTEL  FIGURA CAOITAN AMERICA DE LA MARCA HASBRO Y GUITARRA TOCA CONMIGO DE LA MARCA FISHERPACCE.',
#  ' se verifico vehiculo radio control  de la marca mattel  muÃ²eca con accesorios de la marca mattel y autobus de ciudad de la marca dickie toys.',
#  'SE VERIFICARON ANNA BANANA DE LA MARCA HASBRO  UN AUTO Y UN CONJUNTO DE LA MARCA MATTEL Y SPIDER-MAN DE LA MARCA HASBIO.',
#  'SE VERIFICO CONSOLAS PORTATILES PARA VIDEO JUEGOS Y SISTEMAS DE CARGA PARA CONTROLES',
#  'SE VERIFICO GALLETAS EMPERADOR   PIRUETAS  GALLETAS FORTIFICADAS CON RELLENO SABOR LIMON Y SOPA DE FIDEOS DE LA MARCA KNORR.',
#  'SE VERIFICO PAPILLA DE PERA CON VITAMINAS DE LA MARCA HELNZ Y  PURE DE TOMATE  CONDIMENTADO',
#  'SE VERIFICO LLANTA RADIAL DE MARCA CITY STAR Y LLANTA RADIAL  MARCA NITTO',
#  'SE VERIFICO BLUSAS VARIOS COLORES  FALDAS DE TABLONES Y BLUSAS TIPO PLAYERA QUE NO CUMPEL CON LA NORMA. Y NO EXHIBEN PRECIOS DE LOS PRODUCTOS QUE COMERCIALIZA.',
#  'SE VERIFICO PLAYEROS PARA CABALLEROS DE LA MARCA NK  PANTALONES DE LA MARCA BULBOJEANS PARA CABALLERO Y SUDADERAS VARIOS COLORES UNITALLAS DE LA MARCA NK.',
#  'SE VERIFICO CAMISA PARA CABALLERO DE LA MARCA FIXION  PANTALONES PARA CABALLEROS DE LA MARCA ANTHRAY VARIAS TALLAS Y CHALECOS PARA CABALLEROS DE LA MARCA BINGOÃ¯S.',
#  'SE VERIFICO SALCHICHAS DE PAVO DE LA MARCA FUD Y QUESO ESTILO OAXACA DE LA MARCA LA VILLITA.',
#  'SE VERIFICO VESTIDOS MARCA NINA FERRE   BLUSAS FLOREADAS Y BLUSAS MARCA AVAILABLE QUE CARECEN DE ETIQUETA.',
#  'SE VERIFICO CHAMARRA CON BOLSA NEGRA CON BLANCO DIFERENTES TALLAS DE LA MARCA SANTURYO  MAYAS DEPORTIVAS DIFERENTES COLORES PARA DAMA DE LA MARCA KOKKIRI Y PLAYERAS PARA NIÃ\x91AS DIFERENTES COLORES DE LA MARCA ARTTEX.',
#  'SE VERIFICO MEZCLA DE LECHE DE LA MARCA MARQUEZ Y ATUN DE LA MARCA DOLORES.',
#  'SE VERIFICO BRANDY CLASICO DE 500 ML Y JOHNNIE WALKER RED LABEL DE 750 ETIQUETA ROJA.',
#  'SE VERIFICO BOTAS PARA MUJER COLOR TURQUEZA Y ZAPATOS NEGROS PARA CABALLEROS.',
#  'SE VERIFICO CAMISA DE LA MARCA SHANTAL  SUETER DE LA AMRCA SOPHIA Y VESTIDOS DE DIFERENTES TALLAS  COLORES.',
#  'SE VERIFICO VESTIDOS DE NOCHE  CAMISAS MARCA APPAREL  VESTIDOS BLUEBELL Y BLUSAS MARCA TOSKA QUE CARECEN DE INFORMACION DEL IMPORTADOR N RFC  NORMBRE Y DOMICILIO.',
#  'SE VERIFICO BLUSAS  CAMISAS Y PLAYERAS DIVERSAS MARCAS QUE CARECEN DE ETIQUETA',
#  'SE VERIFICO OSOS DE PELUCHE LOCKA MART Y MUÃ\x91ECOS DE PELUCHE.',
#  'SE VERIFICARON PIEZAS DE CORAZON LONETA  TABLITAS DE CHOCOLATE CON LECHE DESCREMADA Y CAJITAS DE I LOVE GOO HERSHEYS DE KISSSES CHOCOLATE CON LECHE .',
#  'SE VERIFICARON CINTURONES DE VARIOS COLORES  VARIOS MODELOS DE LA MARCA MICHELLY',
#  'SE VERIFICO COJINES DE LA MARCA FULANITOS Y PELUCHES DE LA MARCA FULANITOS.',
#  'SE VERIFICO LATA DE ATUN LOMO DE ATUN ALETA AMARILLA EN ACEITE DE LA MARCA MAZATUN Y LATA DE ATUN LOMO DE ATUN ALETA AMARILLA EN ACEITE DE LA MARCA  MAZATUN',
#  'SE VERIFICO ATUN ANCLA 140 GR Y ATUN SORIANA 140 GR. EN AGUA.',
#  'SE VERIFICO ATUN ALETA AMARILLA EN AGUA CUMPLEN CON LA NORMA.',
#  'SE VERIFICO BLUSAS  SIMPLE FASHION  PANTALON JEANS JORDACHE  BERMUDAS G &M  PLAYERA TIPO SPORT Y TRAJES DE BAÃ\x91O 2 PIEZAS MARCA LONDON BABIES CUMPLEN CON LA NORMA.',
#  'SE VERIFICO TRAJES DE BAÃ\x91O 2 PIEZAS MARCA BASSELINI GIRLSWEAR Y TRAJES DE BAÃ\x91O ENTERO MARCA VIANNI PLUS.',
#  'SE VERIFICO PLAYERAS TIPO POLO Y PLAYERAS MANGA CORTA DE LA MARCA HANG TEN CUMPLEN CON LA NORMA.',
#  'SE VERIFICO TRAJES DE BAÃ\x91O 2 PIEZAS Y TRAJE DE BAÃ\x91O UNA PIEZASMARCA LOB CUMPLEN CON LA NORMA.',
#  'SE VERIFICARON TOALLAS MARCA VALENCIA CUMPLEN CON LA NORMA.',
#  'SE VERIFICO BERMUDAS MARCA RIO BEACH Y TRAJES DE BAÃ\x91O MARCA MONSTER HIGH CUMPLEN CON LA NORMA.',
#  'SE VERIFICO BLUSAS DE TIRANTES MARCA EXTRA BELLEZA Y BLUSAS MARCA CLEELS COLLECTION CUMPLEN CON LA NORMA.',
#  'SE VERIFICO ATUN DOLORES 140 G. EN AGUA MARCA DOLORES  TUNNY Y  NAIR.',
#  'SE VERIFICO TRAJES DE BAÃ\x91O 2 PIEZAS STRAPLES MARCA C&A CUMPLEN CON LA NORMA.',
#  'SE VERIFICO BLUSAS DE TIRANTES MARCA SISTAR Y TRAJES DE BANO 2 PIEZAS MARCA KARLA CUMPLEN CON LA NORMA.',
#  'SE VERIFICO PLAYERAS MARCA YALE SPORT  CAMISAS PACO RABANNE Y PANTALONES MARCA LEE CUMPLEN CON LA NORMA.',
#  'SE VERIFICO PLAYERAS TIPO POLO  MARCA YALE Y CAMISAS MARCA YALE CUMPLEN CON LA NORMA.',
#  'SE VERIFICO TOALLAS MARCA OOP Y  COTTONELLA CUMPLEN CON  LA NORMA.',
#  'SE VERIFICO CAMISETAS MARCA VAVA  TRAJES DE BAÃ\x91O MARCA REE BEES SWIMWEAR Y BLUSAS MARCA VANGEE COUTURE CUMPLEN CON LA NORMA.',
#  'SE VERIFICO BLUSAS MARCA CORAL  VESTIDOS MARCA BLUSK Y SHORTS MARCA MISS COCOA CUMPLEN CON LA NORMA.',
#  'SE VERIFICO BLUSAS MARCA MICH  FALDAS MARCA P. FASHION Y PANTALONES MARCA VIP CUMPLEN CON LA NORMA.',
#  'SE VERIFICO PLAYERAS CUELLO V  CAMISETAS Y BERMUDAS MARCA SQUALO CUMPLEN CON LA NORMA.',
#  'SE VERIFICO SALCHICHA PARA ASAR MARCA CAPISTRANO Y JAMON VIRGINIA FUD CUMPLEN CON LA NORMA.',
#  'SE VERIFICO PAQUETES DE JAMON DE PAVO MARCA FUD Y PAQUETES DE SALCHICHA MARCA KIR CUMPLEN CON LA NORMA.',
#  'SE VERIFICO SANDALIAS  ZAPATOS DEL LONA Y ZAPATILLAS MARCA CAPA DE OZONO CUMPLEN CON LA NORMA.',
#  'SE VERIFICO TRAJES DE BAÃ\x91O 2 PIEZAS  SHORTS Y PLAYERAS MARCA  AMERICAN  RIO BEACH Y EXPRESS CUMPLEN CON LA NORMA.',
#  'se verifico trajes de baÃ²o 2 piezas marca woekend cumple con la norma.',
#  'SE VERIFICO VESTIDOS  MAYONES Y TRAJES DE BAÃ\x91O DE 2 PIEZAS MARCA PRIVA  FASHION STAR Y K ARLA CUMPLEN CON LA NORMA.',
#  'SE VERIFICO PAKETAZO SABRITAS Y TOTILLLINAS TIA ROSA CUMPLEN CON LA NORMA.',
#  'SE VERIFICO  CONSOLA XBOX360 MICROSOFT CUMPLE CON LA NORMA.',
#  'SE VERIFICO IPAD TOUCH CUMPLE CON LA NORMA.',
#  'SE VERIFICO ZAPATOS PARA NIÃ\x91OS Y NIÃ\x91AS MARCA JEANS SHOESOONDER SCHOOL Y YUQI CUMPLEN CON LA NORMA.',
#  'SE VERIFICO ZAPATOS PARA NIÃ\x91OS Y NIÃ\x91A MARCA MINI BURBUJAS Y COQUETA.',
#  'SE VERIFICO SHORTS  VESTIDOS Y PLAYERAS MARCA MAYORAL  GIRANDOLA  BAMBIN Y KIDOKO CUMPLEN CON LA NORMA.',
#  'SE VERIFICO CAMISETA Y CAMISAS PARA NIÃ\x91OS MARCA TUC TUC  MAYORAL Y LOSAN CUMPLEN CON LA NORMA.',
#  'SE VERIFICO VIDEO XBOX 360 MARCA VULCAN CUMPLE CON LA NORMA.',
#  'SE VERIFICO OSITOS  BEBITA RECIEN NACIDA  IRON MAN Y JENGA QUAKE CUMPLEN CON LA NORMA.',
#  'SE VERIFICO TABLET MARCA AOC Y SAMSUN CUMPLEN CON LA NORMA.',
#  'SE VERIFICO FALDAS  CAMISAS Y VESTIDOS MARCA NOI  YALE Y KINDOKA CUMPLEN CON LA NORMA.',
#  'SE VERIFICO ZAPATOS  SANDALIAS Y TENIS MARCA CLAU  KINDER Y SOY KIDS CUMPLEN CON LA NORMA.',
#  'SE VERIFICO VESTIDOS Y CONJUNTOS DE NIÃ\x91AS MARCA DISEÃ\x91OS REAÃ¯S  COMERCIAL CASTRO Y KIS PAS CUMPLEN CON LA NORMA.',
#  'SE VERIFICO MUÃ\x91ECAS CON ACCESORIOS Y RAQUETAS CUMPLEN CON AL NORMA.',
#  'SE VERIFICO ZAPATOS Y TENIS PARA NIÃ\x91OS Y NIÃ\x91AS MARCA COQUETA  CHABELO Y BUBBLE GUMMERS CUMPLEN CON LA NORMA.',
#  'SE VERIFICO CARRITOS MARCA HDI  MUÃ\x91ECAS BARBIE Y MUÃ\x91ECOS DE ACCION MARCA HASBRO  CUMPLEN CON LA NORMA.',
#  'SE VERIFICO VESTIDOS  BLUSAS  CAMISAS  PANTALONES Y TRAJITOS PARA NIÃ\x91OS Y NIÃ\x91AS DE LA MARCA BABY CREASY Y SIMPLE BASIC CUMPLEN CON LA NORMA.',
#  'SE VERIFICO VESTIDOS  BLUSAS Y PANTALONES MARCA  SIX SEVEN  A-MANO Y BLOCKJEANS CUMPLEN CON LA NORMA.',
#  'SE VERIFICO LEGGINS  SHORTS Y VESTIDOS MARCA ZOY.',
#  'SE VERIFICO BOLSAS Y CARTERAS MARCAS MOMOSS Y GRACE CUMPLEN CON LA NORMA.',
#  'SE VERIFICO ZAPATILLAS  ZAPATOS MARCA PARANA Y FLEXI CUMPLEN CON LA NORMA.',
#  'SE VERIFICO BLUSAS Y VESTIDOS MARCA JULIO CUMPLEN CON LA NORMA.',
#  'SE VERIFICO  MONEDEROS Y BOLSAS MARCA VEK  CALIFORNIA Y VICTORIA CUMPLEN CON LA NORMA.',
#  'SE VERIFICO  PANTALONES  VESTIDOS Y FALDAS MARCA IVONNE CUMPLEN CON LA NORMA.',
#  'SE VERIFICO VESTIDOS  FALDAS Y BLUSAS MARCA  LINEAS Y KALDI CUMPLEN CON LA NORMA.',
#  'SE VERIFICO MASCARA PARA PESTAÃ\x91AS MARCA TAHIAL Y ESTUCHE DE SOMBRAS MARCA FEELYNN CUMPLEN CON LA NORMA.',
#  'SE VERIFICO ZAPATILLAS MARCA WESTLE  SANDALIAS MARCA MODARE Y HERRUZA CUMPLEN CON LA NORMA.',
#  'SE VERIFICO ZAPATOS  MARCA VIA UNO Y FLEXI CUMPLEN CON LA NORMA.',
#  'SE VERIFIVO PANTALONES  PLAYERAS  FALDAS Y BLUSAS MARCA SIX SEVEN  MISS COCOA Y KALDY CUMPLEN CON LA NORMA.',
#  'SE VERIFICO FALDAS  VESTIDOS Y CHALINAS MARCA  LIZ MINELLI CUMPLE CON LA NORMA.',
#  'SE VERIFICO PASTELES  CONOS DE HUEVO Y PASTELES QUE CUENTA CON LA FECHA DE CADUCIDAD VIGENTE.',
#  'SE VERIFICO CAMISAS DE CUADRO Y PANTALONES DE MEZCLILLA MARCA CK CUMPLEN CON LA NORMA.',
#  'SE VERIFICO CAMISAS  PLAYERAS Y BERMUDAS PARA CABALLEROS QUE CUMPLEN CON LA NORMA.',
#  'SE VERIFICO ZAPATOS PARA CABALLERO MARCA TRIPLES F.ARENUS Y SWISS BRAND. CUMPLEN CON LA NORMA.',
#  'SE VERIFICO MICROFONOS INHALAMBRICOS MARCA MITZU Y RECEPTORES DE TELEVISION MARCA RCA CUMPLEN CON LA NORMA.',
#  'SE VERIFICO ZAPATOS Y TENIS MARCA FLEXI Y CHALY PARA CABALLERO QUE CUMPLEN CON LA NORMA.',
#  'SE VERIFICO PLAYERAS Y SHORTS PARA CABALLERO MARCA PIRMA QUE CUMPLEN CON LA NORMA.',
#  'SE VERIFICO ZAPATOS Y SANDALIAS MARCA FLEXI QUE CUMPLEN CON LA NORMA.',
#  'SE VERIFICO ZAPATOS PARA CABALLERO MARCA ARETINA Y HUSH PUPPIES QUE CUMPLEN CON LA NORMA.',
#  'SE VERIFICO BILLERTAS PARA CABALLERO MARCA NICOLE MOON QUE CUMPLE CON LA NORMA.',
#  'SE VERIFICO ZAPATOS Y SANDALIAS  PARA CABALLERO MARCA BUCKERÃ¯S Y BULKANIC QUE CUMPLEN CON LA NORMA.',
#  'SE VERIFICO ZAPATOS Y BOTAS  QUE CUMPLEN CON LA NORMA.',
#  'SE VERIFICO ESCLAVA CON TEJIDO DE 14 K  ARGOLLAS DE MATRIMONIO Y PRENDEDOR CON AMBAR QUE CUMPLEN CON LA NORMA.',
#  'SE VERIFICO ANILLO SOLITARIO DE 14 K  ARGOLLAS DE MATRIMONIO DE 14 K QUE CUMPLEN CON LA NORMA.',
#  'SE VERIFICO CADENA DE ORO DE 14 K  ARGOLLA MATRIMONIAL Y CADENA DE PLATA HECHOS EN MEXICO QUE CUMPLEN CON  LA NORMA.',
#  'SE VERIFICO MEDALLA  ARETES Y CADENA DE ORO AMARILLO  ARETES DE PERLA HECHOS EN MEXICO QUE CUMPLEN CON LA NORMA.',
#  'SE VERIFICO ANILLO DE PLATA  PULSERA DE PLATA Y ANILLO A ARGOLLA HECHO EN MEXICO QUE CUMPLEN CON LA NORMA.',
#  'SE VERIFICO ANILLO DE MATRIMONIO  PULSERA DE ORO Y CADENA DE ORO DE 14 K HECHO EN MEXICO QUE CUMPLEN CON LA NORMA.',
#  'SE VERIFICO CADENA DE PLATA  BROQUELES DE 14 K Y ARGOLLAS MATRIMONIAL HECHOS EN MEXICO QUE CUMPLEN CON LA NORMA.',
#  'SE VERIFICO TENIS PARA CABALLERO MARCA EVERLAST  DCCO Y BY BRITISH QUE CUMPLEN CON LA NORMA.',
#  'ESTUFA',
#  'TOSTADOR',
#  'ROPA',
#  'SACO MARCA VERMONTI IMPORTADO POR CALL PRIME SA DE CV CON INSTRUCCIONES DE CUIDADO',
#  'JUGO',
#  ' PANTALON PARA CABALLERO IMPORTADO POR COMERCIALIZADORA MEXICO AMERICANA',
#  'leche descremada y condensada marca la lechera  cont. 397g',
#  'cacahuate cubierto marca hot nuts cont. 50 g con fecha de caducidad vigente',
#  'jabon liquido',
#  'refrigerador marca mabe modelo RMT1540',
#  ' bebida de tomate marca clamato cont 946ml',
#  'suero rehidratante marca electrolit cont 625 ml',
#  'esponja para calzado marca kiwi con informacion comercial',
#  'detergente liquido marca salvo cont 300ml con informacion comercial.',
#  'horno de microondas marca mabe con informacion comercial e instructivo.',
#  'FRIJOLES',
#  'Agua purificada marca alaska cont. 1 lt.',
#  'jugo',
#  ' lonche lonchibon marca bimbo cont 151g.',
#  'tequila reposado jose cuervo tradicional cont 950 ml 100% agave azul  con leyenda precautoria.',
#  'cemento',
#  'vinagre',
#  'haba',
#  'sow cooker',
#  'cumple con la norma oficial mexicana',
#  'mayonesa marca kraft cont. 685 g',
#  'elote en grano marca soriana cont. 432g',
#  'ATUN  MARCA MAZATUN  CONT. 140 G CON INF. COMERCIAL  NUTRIMENTAL  FABRICANTE  PAIS DE ORIGEN  FECHA DE CADUCIDAD VIGENTE  ETC.',
#  'sardina',
#  'cumple con la norma oficial mexicana',
#  'CUMPLE CON LA NORMA OFICIAL MEXICANA',
#  'atun',
#  'atun',
#  'CUMPLE CON LA NORMA',
#  'lavadora',
#  ...]

# %% [markdown]
# # Consultas

# %% [markdown]
# ## Dado un estado y un producto, buscar lugares donde pueda encontrarlo.

# %%
def buscaLugares(entidad, producto, numMax = 10):
    with driver.session() as s:
        consulta = s.run("""MATCH (n:Producto) <-[r1:Vende]- (t:Tienda) -[r2:Se_Encuentra_En]-> (m:Municipio) -[r3:Es_Municipio]-> (e:Entidad)
                 WHERE n.nombre = \"{0}\" AND e.nombre = \"{1}\"
                 RETURN t
                 LIMIT {2};
                 """.format(producto, entidad, numMax)).values()
                
    # Regresemos un dataframe para ver el resultado de la consulta claramente        
    
    data_consulta = pd.DataFrame(columns = ['Estado', 'Producto', 'Tienda'])
    
    
    for i,x in enumerate(consulta):
        properties = x[0]._properties
        names = [properties['entidad'], producto, properties['nombre']]
        data_consulta.loc[i] = names
        
    return data_consulta[0:10]

# %%
buscaLugares("CHIHUAHUA","huevo")
# Out:
#       Estado Producto                           Tienda
# 0  CHIHUAHUA    huevo  OPERADORA DE CD JUAREZ SA DE CV
# 1  CHIHUAHUA    huevo     TIENDAS SORIANA S.A. DE C.V.
# 2  CHIHUAHUA    huevo   SUPER MERCADO GONZALEZ EXPRESS

# %% [markdown]
# ## Dado un estado y una tienda, verificar si tiene algun incumplimiento con un producto.

# %%
def revisaIncumplimiento(entidad, tienda):
    with driver.session() as s:
        consulta = bool(s.run("""MATCH (n:Producto) <-[r1:Vende]- (t:Tienda) -[r2:Se_Encuentra_En]-> (m:Municipio) -[r3:Es_Municipio]-> (e:Entidad)
                     WHERE t.nombre = \"{1}\" AND e.nombre = \"{0}\" AND r1.incumplimiento <> \"NO SE DETECTO INCUMPLIMIENTO\"
                     RETURN count(*);
                     """.format(entidad,tienda)).value()[0])
        
    if not consulta:
        return'No se detecto incumplimiento'
    else:
        return 'Se detectó incumplimiento'

# %%
revisaIncumplimiento("CAMPECHE","CARLA VALLADARES CARAVEO Y/O ULTRAMART HOSPITALES")
# Out:
# 'No se detecto incumplimiento'

# %% [markdown]
# ## Dado un estado y un producto, buscar alternativas sin incumplimiento de ese producto o categoría.

# %%
def buscaLugaresLimpios(entidad, producto, buscarCategoria = False, numMax = 10):
    with driver.session() as s:
        if buscarCategoria == True:
            consulta = s.run("""MATCH (n:Producto) <-[r1:Vende]- (t:Tienda) -[r2:Se_Encuentra_En]-> (m:Municipio) -[r3:Es_Municipio]-> (e:Entidad)
                            MATCH (n) -[r4:Categorizado_Como]-> (c:Categoria)
                            MATCH (c) <-[r5:Categorizado_Como]- (p_alt:Producto) <-[r6:Vende]- (t2:Tienda) -[r7:Se_Encuentra_En]-> (m2:Municipio) -[r8:Es_Municipio]-> (e)
                            WHERE n.nombre = \"{0}\" AND r6.incumplimiento = \"NO SE DETECTO INCUMPLIMIENTO\" AND e.nombre = \"{1}\"
                            RETURN p_alt, t2
                            LIMIT 10
                            """.format(producto, entidad, numMax)).values()
        else:
            #Quiero buscar productos alternativos
            consulta =  s.run("""MATCH (n:Producto) <-[r1:Vende]- (t:Tienda) -[r2:Se_Encuentra_En]-> (m:Municipio) -[r3:Es_Municipio]-> (e:Entidad)
                                WHERE n.nombre = \"{0}\" AND r1.incumplimiento = \"NO SE DETECTO INCUMPLIMIENTO\" AND e.nombre = \"{1}\"
                                RETURN n.nombre, t
                                LIMIT 10
                                """.format(producto, entidad, numMax)).values()
            
        if buscarCategoria:
            data_consulta = pd.DataFrame(columns = ['Producto', 'Categoría', 'Tienda'])
    
    
            for i,x in enumerate(consulta):
                prod = x[0]._properties
                tienda = x[1]._properties
                names = [prod['nombre'], prod['categoria'], tienda['nombre']]
                data_consulta.loc[i] = names
                
            return data_consulta.loc[0:10]
        
        else:
            data_consulta = pd.DataFrame(columns = ['Producto', 'Tienda'])
    
    
            for i,x in enumerate(consulta):
                tienda = x[1]._properties
                names = [producto, tienda['nombre']]
                data_consulta.loc[i] = names
                
            return data_consulta.loc[0:10]

# %%
(buscaLugaresLimpios("CAMPECHE","lomo de atun aleta amarilla", buscarCategoria = False))
# Out:
#                       Producto  \
# 0  lomo de atun aleta amarilla
#
#                                               Tienda
# 0  CARLA VALLADARES CARAVEO Y/O ULTRAMART HOSPITALES

# %%
buscaLugaresLimpios("CAMPECHE", "lomo de atun aleta amarilla", buscarCategoria = True)[0:3]
# Out:
#                                             Producto Categoría  \
# 0                                    si cumple norma      ATUN
# 1   si cumple con la norma lata de lomo de atun d...      ATUN
# 2                de 140 grs aleta amarilla en aceite      ATUN
#
#                                               Tienda
# 0  CADENA COMERCIAL OXXO SA DE CV YO TIENDA DE CO...
# 1  ULTRAMARINOS EL SOL Y/O KRISHNA HUMBERTO SANDO...
# 2                             SUPER WILLY'S SA DE CV

# %% [markdown]
# ## Llevar un registro de las compras y lugares que ha hecho cada usuario.

# %%
import random

# %%
def get_random_alphaNumeric_string(stringLength=8):
    lettersAndDigits = string.ascii_letters + string.digits
    return ''.join((random.choice(lettersAndDigits) for i in range(stringLength)))


#Sistema de usuarios
def agregaCompraUsuario(usuario_id, nombre_usuario, compra_id, producto, cantidad, lugar, municipio, entidad):
    #with driver.session() as s:
    with driver.session() as s:
        return s.run("""MATCH (p:Producto) <-[r1:Vende]- (t:Tienda) -[r2:Se_Encuentra_En]-> (m:Municipio) -[r3:Es_Municipio]-> (e:Entidad)
                 WHERE p.nombre = \"{0}\" AND t.nombre = \"{1}\" AND m.nombre = \"{2}\" AND e.nombre = \"{3}\"
                 MERGE (u:Usuario {{id: \"{4}\"}}) -[r4:Realiza]-> (c:Compra {{id: \"{5}\"}})
                 ON CREATE SET u.nombre =  \"{6}\", c.hora = timestamp()
                 MERGE (c) -[r5:Contiene {{cantidad: \"{7}\"}}]-> (p)
                 MERGE (c) -[r6:En]-> (t)
                """.format(producto, lugar, municipio, entidad, usuario_id, compra_id, nombre_usuario ,cantidad))
def consultarProductosUsuario(usuario_id):
    with driver.session() as s:
        return s.run("""MATCH (u:Usuario) -[r1:Realiza]-> (c:Compra) -[r2:Contiene]-> (p:Producto)
                 WHERE u.id = \"{0}\"
                 RETURN DISTINCT p.nombre
                 """.format(usuario_id)).values()

def consultarLugaresUsuario(usuario_id):
    with driver.session() as s:
        return s.run("""MATCH (u:Usuario) -[r1:Realiza]-> (c:Compra) -[r2:En]-> (t:Tienda) -[r3:Se_Encuentra_En]-> (m:Municipio) -[r4:Es_Municipio]-> (e:Entidad)
                 WHERE u.id = \"{0}\"
                 RETURN DISTINCT t.nombre, m.nombre, e.nombre
                 """.format(usuario_id)).values()

# %% [markdown]
# Ahora agreguemos algunos usuarios:

# %%
agregaCompraUsuario("usuario1","Alejandro","compra1","",
                    3,"CARLA VALLADARES CARAVEO Y/O ULTRAMART HOSPITALES","CAMPECHE","CAMPECHE")
agregaCompraUsuario("usuario1","Alejandro","compra2","cono de 12 piezas de la marca crio.",
                    1,"CADENA COMERCIAL OXXO SA DE CV Y/O SUC BOSQUES DE CAMPECHE","CAMPECHE","CAMPECHE")
agregaCompraUsuario("usuario1","Alejandro","compra3","bolsa de arroz lote 1014",
                    5,"CADENA COMERCIAL OXXO SA DE CV","CAMPECHE","CAMPECHE")
agregaCompraUsuario("usuario1","Alejandro","compra12","BOTELLA DE TEQUILA CONTENIDO NETO 950 ML CON 35% ALC.",
                    1,"CADENA COMERCIAL OXXO SA DE CV","AGUASCALIENTES","AGUASCALIENTES")

agregaCompraUsuario("usuario2","Mario","compra4","BOTELLA DE TEQUILA CONTENIDO NETO 950 ML CON 35% ALC.",
                    1,"CADENA COMERCIAL OXXO SA DE CV","AGUASCALIENTES","AGUASCALIENTES")
agregaCompraUsuario("usuario2","Mario","compra5","BOTELLA DE BRANDY CONTENIDO NETO 700 ML 38% ALC.",
                    1,"CADENA COMERCIAL OXXO SA DE CV","AGUASCALIENTES","AGUASCALIENTES")
agregaCompraUsuario("usuario2","Mario","compra6","BOTELLA DE BRANDY CONTENIDO NETO 700 ML 38% ALC.",
                    1,"CADENA COMERCIAL OXXO SA DE CV","AGUASCALIENTES","AGUASCALIENTES")
agregaCompraUsuario("usuario2","Mario","compra7","BOTELLA DE VIDRIO CON TEQUILA REPOSADO 100% DE AGAVE AZUL  CONTENIDO NETO DE 695 ML CON 38% ALC.",
                    1,"TIENDAS EXTRA S.A DE C.V","AGUASCALIENTES","AGUASCALIENTES")

agregaCompraUsuario("usuario3","David","compra8","Pinza de presion marca MAX TOOL modelo 306701 en blister conteniendo 1 pza",
                    2,"TLAPALERIA  HIDROMECANICA","COYOACAN","DISTRITO FEDERAL")
agregaCompraUsuario("usuario3","David","compra9","Desarmador de cruz marca MAX TOOL modelo 300201 en blister conteniendo 1 pza",
                    1,"TLAPALERIA  HIDROMECANICA","COYOACAN","DISTRITO FEDERAL")
agregaCompraUsuario("usuario3","David","compra10","Brocha marca MAX TOOL modelo 301507 en blister",
                    1,"TLAPALERIA  HIDROMECANICA","COYOACAN","DISTRITO FEDERAL")
agregaCompraUsuario("usuario3","David","compra11","BOTELLA DE TEQUILA CONTENIDO NETO 950 ML CON 35% ALC.",
                    1,"CADENA COMERCIAL OXXO SA DE CV","AGUASCALIENTES","AGUASCALIENTES")

# %%
consultarProductosUsuario("usuario2")
# Out:
# [['BOTELLA DE TEQUILA CONTENIDO NETO 950 ML CON 35% ALC.'],
#  ['BOTELLA DE BRANDY CONTENIDO NETO 700 ML 38% ALC.'],
#  ['BOTELLA DE VIDRIO CON TEQUILA REPOSADO 100% DE AGAVE AZUL  CONTENIDO NETO DE 695 ML CON 38% ALC.']]

# %%
consultarLugaresUsuario("usuario1")
# Out:
# [['CADENA COMERCIAL OXXO SA DE CV', 'CAMPECHE', 'CAMPECHE'],
#  ['CADENA COMERCIAL OXXO SA DE CV', 'AGUASCALIENTES', 'AGUASCALIENTES']]

# %% [markdown]
# ## Recomendar a un usuario una tienda en donde pueda encontrar en un solo lugar, lo que compra en diferentes tiendas.

# %%
def recomendar_lugar(productos, entidad):
    
    condicion = ''

    for x in productos:
        condicion = condicion + 'n.nombre = \"{}\"'.format(x) + ' OR '
        
    condicion = condicion[0:-4]
    
    with driver.session() as s:
        consulta =  s.run("""MATCH (n:Producto) <-[r1:Vende]- (t:Tienda) -[r2:Se_Encuentra_En]-> (m:Municipio) -[r3:Es_Municipio]-> (e:Entidad)
                     WHERE e.nombre = \"{0}\" AND ({1})
                     RETURN t.nombre, n.nombre
                     ORDER BY t.nombre
                     """.format(entidad,condicion)).values()
        
    data_consulta = pd.DataFrame(consulta, columns = ['Tienda', 'Producto'])
    data_consulta = data_consulta.groupby('Tienda')['Producto'].apply(lambda x: ';'.join(x)).reset_index()
    data_consulta['Producto'] = data_consulta['Producto'].apply(lambda x: x.split(';'))

    condicion = [True if set(productos) == set(x) else False for x in data_consulta['Producto']]

    if data_consulta[condicion].shape[0] > 0:
        return data_consulta[condicion][['Tienda']].reset_index(drop=True).loc[0:5]
    else:
        print('No hay tiendas')
        return []

# %%
productos = ['BOTELLA DE TEQUILA CONTENIDO NETO 950 ML CON 35% ALC.', 'BOTELLA DE BRANDY CONTENIDO NETO 700 ML 38% ALC.',
            'BOTELLA DE WHISKY CONENIDO 750 ML CON 40% ALC.']
entidad = 'AGUASCALIENTES'

print(recomendar_lugar(productos, entidad))
# Out:
#                            Tienda
# 0  CADENA COMERCIAL OXXO SA DE CV

# %% [markdown]
# ## Encontrar los estados con mayor y menor incumplimiento relativo al número de tiendas que tiene.

# %%
def encuentraIncumplimientoEstados():
    with driver.session() as s:
        incump = s.run("""MATCH (n:Producto) <-[r1:Vende]- (t:Tienda) -[r2:Se_Encuentra_En]-> (m:Municipio) -[r3:Es_Municipio]-> (e:Entidad)
                        WHERE r1.incumplimiento <> \"NO SE DETECTO INCUMPLIMIENTO\"
                        RETURN e.nombre, count(r1)
                        """).values()
        totals = s.run("""MATCH (t:Tienda) -[r2:Se_Encuentra_En]-> (m:Municipio) -[r3:Es_Municipio]-> (e:Entidad)
                        RETURN e.nombre, count(t)
                        """).values()
        lista = []
        for k,v in totals:
            num_inc = 0
            for k2,v2 in incump:
                if k == k2:
                    num_inc=v2
                    break
            lista.append([k,num_inc/v])
        df_ret = pd.DataFrame(lista, columns = ['Entidad','Incump_Por_Tiendas'])
    return df_ret

# %%
print(encuentraIncumplimientoEstados().head())
# Out:
#                Entidad  Incump_Por_Tiendas
# 0       AGUASCALIENTES            0.194175
# 1      BAJA CALIFORNIA            0.174051
# 2  BAJA CALIFORNIA SUR            0.053512
# 3             CAMPECHE            0.032787
# 4     DISTRITO FEDERAL            0.186275

# %%
# !pip install folium geopandas

# %%
import branca.colormap as cm
import folium
import geopandas

# %%
df_geo = geopandas.read_file('Datos/mexican_states.geojson')
df_geo.head()
# Out:
#   CVE_ENT           NOM_ENT  OID  \
# 0      09  Distrito Federal    1
# 1      12          Guerrero    2
# 2      15            México    3
# 3      17           Morelos    4
# 4      25           Sinaloa    5
#
#                                             geometry
# 0  POLYGON ((-98.97900 19.07446, -98.98359 19.078...
# 1  POLYGON ((-99.49441 18.72054, -99.47758 18.673...
# 2  POLYGON ((-99.85911 20.26847, -99.84189 20.281...
# 3  POLYGON ((-98.97900 19.07446, -98.95778 19.060...
# 4  POLYGON ((-106.99432 25.66223, -106.97329 25.6...

# %%
incumplientos = [0.186275, 0.083333, 0.035122, 0.100503, 0.134831, 0.174051, 0.086614, 0.053512, 0.044776,
                 0.182482, 0.073394, 0.092391, 0.964286, 0.358491, 0.907801, 0.023529, 0.052632, 0.480000,
                 0.174797, 0.194175, 0.033816, 0.000000, 0.042296, 0.038462, 0.067460, 0.026178, 0.161290,
                 0.041667, 0.049763, 0.085106, 0.032787, 0.165919]

df_geo['INCUMPLIMIENTOS'] = incumplientos

# df_geo.to_file('mexican_states_info.geojson', driver='GeoJSON')

# %% [markdown]
# Hacemos un mapa de colores:

# %%
import branca.colormap as cm

colormap = cm.LinearColormap(colors = ['#12C600', '#DFE600', '#F8900B', '#E90000'],
                             index = [0, 1/3, 2/3, 1],
                             vmin = 0, vmax = 1)

colormap
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#12c600ff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#13c600ff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#14c700ff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#15c700ff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#17c700ff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#18c700ff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#19c700ff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#1ac800ff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#1bc800ff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#1dc800ff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#1ec800ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#1fc800ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#20c900ff;stroke-width:3;" /><line x1="13" y1="0" x2="13" y2="20" style="stroke:#22c900ff;stroke-width:3;" /><line x1="14" y1="0" x2="14" y2="20" style="stroke:#23c900ff;stroke-width:3;" /><line x1="15" y1="0" x2="15" y2="20" style="stroke:#24c900ff;stroke-width:3;" /><line x1="16" y1="0" x2="16" y2="20" style="stroke:#25c900ff;stroke-width:3;" /><line x1="17" y1="0" x2="17" y2="20" style="stroke:#27ca00ff;stroke-width:3;" /><line x1="18" y1="0" x2="18" y2="20" style="stroke:#28ca00ff;stroke-width:3;" /><line x1="19" y1="0" x2="19" y2="20" style="stroke:#29ca00ff;stroke-width:3;" /><line x1="20" y1="0" x2="20" y2="20" style="stroke:#2aca00ff;stroke-width:3;" /><line x1="21" y1="0" x2="21" y2="20" style="stroke:#2cca00ff;stroke-width:3;" /><line x1="22" y1="0" x2="22" y2="20" style="stroke:#2dcb00ff;stroke-width:3;" /><line x1="23" y1="0" x2="23" y2="20" style="stroke:#2ecb00ff;stroke-width:3;" /><line x1="24" y1="0" x2="24" y2="20" style="stroke:#2fcb00ff;stroke-width:3;" /><line x1="25" y1="0" x2="25" y2="20" style="stroke:#31cb00ff;stroke-width:3;" /><line x1="26" y1="0" x2="26" y2="20" style="stroke:#32cb00ff;stroke-width:3;" /><line x1="27" y1="0" x2="27" y2="20" style="stroke:#33cb00ff;stroke-width:3;" /><line x1="28" y1="0" x2="28" y2="20" style="stroke:#34cc00ff;stroke-width:3;" /><line x1="29" y1="0" x2="29" y2="20" style="stroke:#35cc00ff;stroke-width:3;" /><line x1="30" y1="0" x2="30" y2="20" style="stroke:#37cc00ff;stroke-width:3;" /><line x1="31" y1="0" x2="31" y2="20" style="stroke:#38cc00ff;stroke-width:3;" /><line x1="32" y1="0" x2="32" y2="20" style="stroke:#39cc00ff;stroke-width:3;" /><line x1="33" y1="0" x2="33" y2="20" style="stroke:#3acd00ff;stroke-width:3;" /><line x1="34" y1="0" x2="34" y2="20" style="stroke:#3ccd00ff;stroke-width:3;" /><line x1="35" y1="0" x2="35" y2="20" style="stroke:#3dcd00ff;stroke-width:3;" /><line x1="36" y1="0" x2="36" y2="20" style="stroke:#3ecd00ff;stroke-width:3;" /><line x1="37" y1="0" x2="37" y2="20" style="stroke:#3fcd00ff;stroke-width:3;" /><line x1="38" y1="0" x2="38" y2="20" style="stroke:#41ce00ff;stroke-width:3;" /><line x1="39" y1="0" x2="39" y2="20" style="stroke:#42ce00ff;stroke-width:3;" /><line x1="40" y1="0" x2="40" y2="20" style="stroke:#43ce00ff;stroke-width:3;" /><line x1="41" y1="0" x2="41" y2="20" style="stroke:#44ce00ff;stroke-width:3;" /><line x1="42" y1="0" x2="42" y2="20" style="stroke:#46ce00ff;stroke-width:3;" /><line x1="43" y1="0" x2="43" y2="20" style="stroke:#47cf00ff;stroke-width:3;" /><line x1="44" y1="0" x2="44" y2="20" style="stroke:#48cf00ff;stroke-width:3;" /><line x1="45" y1="0" x2="45" y2="20" style="stroke:#49cf00ff;stroke-width:3;" /><line x1="46" y1="0" x2="46" y2="20" style="stroke:#4acf00ff;stroke-width:3;" /><line x1="47" y1="0" x2="47" y2="20" style="stroke:#4ccf00ff;stroke-width:3;" /><line x1="48" y1="0" x2="48" y2="20" style="stroke:#4dd000ff;stroke-width:3;" /><line x1="49" y1="0" x2="49" y2="20" style="stroke:#4ed000ff;stroke-wid ...

# %%
dict_edos_cuenta = dict(zip(df_geo['NOM_ENT'], df_geo['INCUMPLIMIENTOS']))

def style_function(feature):
    return {
    'fillColor': colormap(dict_edos_cuenta[feature['properties']['NOM_ENT']]),
    'color': 'black',
    'weight': 1.5,
    }

def highlight_function(feature):
    return {
    'fillColor': colormap(dict_edos_cuenta[feature['properties']['NOM_ENT']]),
    'color': 'black',
    'weight': 3.5,
    }

# %%
mexico_topo_info = f'mexican_states_info.geojson'

m = folium.Map([19.42847,-99.12766], tiles='OpenStreetMap', zoom_start=5)

folium.GeoJson(
    df_geo,
    style_function = style_function,
    highlight_function = highlight_function,
    tooltip = folium.GeoJsonTooltip(
              fields=['NOM_ENT', 'INCUMPLIMIENTOS'],
              aliases=['Estado:', 'Nivel de incumplimiento: '])
).add_to(m)

colormap.caption = 'Nivel de incumplimiento'
m.add_child(colormap)

m.save('Mapas/incumplimiento.html')

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Recomendar productos a un usuario según lo que otros usuarios han comprado. Es decir, Dado un usuario y un producto, obtener todos los productos de esa misma categoría que han comprado otros usuarios que también han comprado ese mismo producto.

# %%
def recomiendaProductos(usuario_id, producto):
    with driver.session() as s:
        return s.run("""MATCH (u:Usuario) -[r1:Realiza]-> (c:Compra) -[r2:Contiene]-> (p:Producto) -[r0:Categorizado_Como]-> (cat:Categoria)
                 WHERE u.id = \"{0}\" and p.nombre = \"{1}\"
                 MATCH (u2:Usuario) -[r3:Realiza]-> (c2:Compra) -[r4:Contiene]-> (p)
                 MATCH (u2) -[r5:Realiza]-> (c3:Compra) -[r6:Contiene]-> (p2:Producto) -[r7:Categorizado_Como]-> (cat)
                 RETURN DISTINCT p2.nombre
              """.format(usuario_id, producto)).values()

# %%
# Todos los usarios compraron ese producto
recomiendaProductos("usuario3", "BOTELLA DE TEQUILA CONTENIDO NETO 950 ML CON 35% ALC.")
# Out:
# [['BOTELLA DE TEQUILA CONTENIDO NETO 950 ML CON 35% ALC.']]
